# %% [markdown]
# # Sampling the sequence space for mutations
#
# In biological sequence spaces (DNA, RNA, and proteins), the possible search space is vast and high dimensional. The further a biological sequence mutates away from its original sequence, the more unpredictable the final behavior of the system becomes, with mutations often layering on top of each other at the sequence level in a way that translates non-linearly to the higher order structures - the phenomenon of epistasis. To explore the local mutational landscape required sampling both a well-chosen set of starting sequences and sufficient sampling in their surroundings.
#
# Finding good starting sequences has a few caveats. The goal of genetic circuits is to actuate some behavior through the interactions of its components in response to a signal. Therefore, sequences that have combinations of weak or strong interactions are desirable. However, the vast majority of sequence space has weak interactions and is thus non-functional, meaning pairs of sequences have extremely weak binding. Finding sequences that can bind to each other strongly is a prerequisite, but the total sampling of the possible circuit space should still be diverse enough to capture many different types of circuits.
#
# For RNA and DNA, complementarity can be used as a way to guarantee binding. Random sampling of the sequence space can be followed up with induced complementarity, for example by delegating one circuit component as a template, then reserving portions of the other components to be complementary to the template strand. The degree and patterning of this induced complementarity can be varied depending on the number of strands and the level of intervention desired. The `SeqGenerator` class therefore has four different ways to generate the components of a genetic circuit, termed 'protocols'. Their differences are demonstrated below.

# %%
import sys
import os
import Bio
import numpy as np


if __package__ is None:

    module_path = os.path.abspath(os.path.join('..'))
    sys.path.append(module_path)

    __package__ = os.path.basename(module_path)


from src.utils.common.setup_new import construct_circuit_from_cfg, prepare_config
from src.utils.data.data_format_tools.common import load_json_as_dict
from src.utils.data.data_format_tools.manipulate_fasta import load_seq_from_FASTA
from src.utils.data.fake_data_generation.seq_generator import RNAGenerator
from src.utils.evolution.evolver import Evolver
from src.utils.misc.type_handling import flatten_listlike
from src.utils.results.result_writer import ResultWriter


config = load_json_as_dict(os.path.join('..', 'tests', 'configs', 'simple_circuit.json'))

# %%
data_writer = ResultWriter(purpose='tests')

# %%
paths_circuits = RNAGenerator(data_writer=data_writer).generate_circuits_batch(
            name='toy_RNGA',
            num_circuits=10,
            num_components=3, 
            slength=20,
            proportion_to_mutate=0.5,
            protocol='random',
            template=None)

samples = [None] * 10
for i, p in enumerate(paths_circuits):
    samples[i] = load_seq_from_FASTA(list(p.values())[0], as_type='dict')
    # construct_circuit_from_cfg(config)

# %%
samples[0]
# Out:
# {'RNA_0': 'GCAGAUUCUAUUGCAUCCCC',
#  'RNA_1': 'CACUAAGGAAUCAAGCAGAA',
#  'RNA_2': 'CGCCCCUUAGGGACGCAGUU'}

# %%
from Bio import Align

samples_names = sorted(set(flatten_listlike([list(s.keys()) for s in samples])))
aligner = Align.PairwiseAligner()
ref_aligments = aligner.align(samples[0][samples_names[0]], samples[0][samples_names[0]])
alignments = flatten_listlike(flatten_listlike([[[aligner.align(s[k1], Bio.Seq.complement_rna(s[k2])) for s in samples] for k1 in samples_names] for k2 in samples_names]))
# print(alignments[0][0])
print('Reference alignment (perfect complementarity): ', ref_aligments[0].score)
print('Alignment scores for complements in circuits: ')
np.unique([a.score for a in alignments])
for a in alignments:
    print(a[0])
# Out:
# Reference alignment (perfect complementarity):  20.0
# Alignment scores for complements in circuits:
# target            0 GCAGAUUCUAUU-GCAU--CCCC------- 20
#                   0 -|-|-|-|||---|-||--|---------- 30
# query             0 -C-G-U-CUA--AG-AUAAC---GUAGGGG 20
#
# target            0 UUGUAGGGU-CUA-CCGC---U--C-A-U- 20
#                   0 ----|-----|-|-||-|---|--|-|-|- 30
# query             0 ----A----AC-AUCC-CAGAUGGCGAGUA 20
#
# target            0 UC-GGU--AUGAGACGGUCU-C--GU---- 20
#                   0 ---|----||-|--|--|||-|--|----- 30
# query             0 --AG--CCAU-A--C--UCUGCCAG-AGCA 20
#
# target            0 GUGUUUCUAGCA--GA--GUAC----GC- 20
#                   0 ------|-|-||--||--||-|----||- 29
# query             0 ------C-A-CAAAGAUCGU-CUCAUGCG 20
#
# target            0 CCCCAAAC----UA--GC-UCG--CGUU-A-- 20
#                   0 ------------|---|--|||--||---|-- 32
# query             0 --------GGGGU-UUG-AUCGAGCG--CAAU 20
#
# target            0 GAAG-UGAA-CCAUCUUCGCC--A-------- 20
#                   0 -----|----|-|-|||-|----|-------- 32
# query             0 ----CU---UC-A-CUU-G--GUAGAAGCGGU 20
#
# target            0 GACCUCU--AUGA--CC-GGACUC-G--- 20
#                   0 --|-|----|-||--|--||-|-|-|--- 29
# query             0 --C-U--GGA-GAUAC-UGG-C-CUGAGC 20
#
# target            0 AUCU-GUUGG-CA-CC-UAG-AUGC---- 20
#                   0 -|---|-----||-||-|-|-||-|---- 29
# query             0 -U--AG----ACAACCGU-GGAU-CUACG 20
#
# target            0 CAGCGUCGCAGCA--CAG-GCUU----- 20
#                   0 --|--|||||||---|-|-|-|------ 28
# query             0 --G--UCGCAGC-GUC-GUG-U-CCGAA 20
#
# target            0 GGAAACAGGCU--GG-C--ACCCAG------ 20
#                   0 -----|---||--|--|--|||--|------ 31
# query             0 -----C---CUUUG-UCCGACC--GUGGGUC 20
#
# target            0 CA--CUAAGGAAUCAAGCAG-AA---- 20
#                   0 |---|||||-|-|-||-|-|-|----- 27
# query             0 C-GUCUAAG-A-U-AA-C-GUA-GGGG 20
#
# target            0 AAU-AA-C--AGCUAUAU--CGAGAU- 20
#                   0 ||--|--|--||--||----||||-|- 27
# query             0 AA-CA-UCCCAG--AU--GGCGAG-UA 20
#
# target            0 -GCCAU-C-CUUGU--AGC-GUUGGC- 20
#                   0 -|||||-|-||-|---||--|----|- 27
# query             0 AGCCAUACUCU-G-CCAG-AG----CA 20
#
# target            0 CAGACGUGACGA-G-U-GU---AGUG-- 20
#                   0 ||--|---|--|-|-|-||---|-||-- 28
# query             0 CA--C---A--AAGAUCGUCUCA-UGCG 20
#
# target            0 UAGCGGGGGUAUC--AUUCGA-C----- 20
#                   0 --|-|||--|-|---||-|||-|----- 28
# query             0 --G-GGG--U-U-UGAU-CGAGCGCAAU 20
#
# target            0 CUCUUCCGAA-UUAGAGAU-GA------ 20
#                   0 ||-|-|--|--||-|-|-|-||------ 28
# query             0 CU-U-C--A-CUU-G-G-UAGAAGCGGU 20
#
# target            0 G-UG-AGGG-UCCAC---CAAA--GA-CU 20
#                   0 --||-||---|--||---|-----||-|- 29
# query             0 -CUGGAG--AU--ACUGGC---CUGAGC- 20
#
# target            0 GGUCU-G-C--C--UGAGAAAGUCCU--- 20
#                   0 --|---|-|--|--||-||---||-|--- 29
# query             0 --U--AGACAACCGUG-GA---UC-UACG 20
#
# target            0 ACCGU---AUG-GUACACG-GACUC---- 20
#                   0 ---||---|-|-||-|--|-|--||---- 29
# query             0 ---GUCGCA-GCGU-C--GUG--UCCGAA 20
#
# target            0 UACGGCGUUC-GCUCCU-AC--U----C 20
#                   0 --|--|-||--|-|||--||--|----| 28
# query             0 --C--C-UU-UG-UCC-GACCGUGGGUC 20
#
# target            0 CG-CCCCUUA-GGGA---CGC-AGUU--- 20
#                   0 ||-|---|-|-|--|---||--||----- 29
# query             0 CGUC---U-AAG--AUAACG-UAG--GGG 20
#
# target            0 UG--CAUUU---AAG-UUGGACGUC-G-- 20
#                   0 ----|||-----|-|-|-||-||---|-- 29
# query             0 --AACAU--CCCA-GAU-GG-CG--AGUA 20
#
# target            0 AU-CACGAAUUAC---GC-AGA-CCA 20
#                   0 |--|-|-|-|-||---||-|||-|-| 26
# query             0 A-GC-C-A-U-ACUCUGCCAGAGC-A 20
#
# target            0 -A-AU--G-U-G-CACCUG-AUAGACGA 20
#                   0 -|-|---|-|-|-|---|--||-|-||- 28
# query             0 CACA-AAGAUCGUC---U-CAU-G-CG- 20
#
# target            0 GG--UC---AACUCGAAGAGCCUG-A-- 20
#                   0 ||--|----|--||||-|--|--|-|-- 28
# query             0 GGGGU-UUGA--UCGA-G--C--GCAAU 20
#
# target            0 GA-UAGAUCGACGU-GGUCCAG------- 20
#                   0 ---|---||-||-|-|||--||------- 29
# query             0 --CU---UC-AC-UUGGU--AGAAGCGGU 20
#
# target            0 -UGUCGACGCA--C-G-CCUCGUUA-- 20
#                   0 -||--||-|-|--|-|-|||-|--|-- 27
# query             0 CUG--GA-G-AUACUGGCCU-G--AGC 20
#
# target            0 -A--CAACGGCAG-GG-UC--CCCGAU 20
#                   0 -|--||||--|-|-||-||--|--|-- 27
# query             0 UAGACAAC--C-GUGGAUCUAC--G-- 20
#
# target            0 ACG-CG-A---UACCAA-U-U--GGACAA 20
#                   0 --|-||-|---|-|----|-|--|-|-|- 29
# query             0 --GUCGCAGCGU-C---GUGUCCG-A-A- 20
#
# target            0 AAAAA--UAUGUGUCCGGCAA--G------ 20
#                   0 -------|-|-||||||--|---|------ 30
# query             0 -----CCU-U-UGUCCG--A-CCGUGGGUC 20
#
# target            0 GCA-GAUUC-U-A-UUGCA-UCCCC-- 20
#                   0 |---|||||-|-|-||-|--||----- 27
# query             0 G--UGAUUCCUUAGUU-C-GUC---UU 20
#
# target            0 UUGUA--GGGUC--UACC--GCUCAU- 20
#                   0 ||--|--|--||--||----||||-|- 27
# query             0 UU--AUUG--UCGAUA--UAGCUC-UA 20
#
# target            0 UCGGUAUGAGA-CGG-UCU-C----GU 20
#                   0 -|||||-|-||-|---||--|----|- 27
# query             0 -CGGUA-G-GAAC--AUC-GCAACCG- 20
#
# target            0 GUGUUUCUAGCA--GAG-U-ACG--C-- 20
#                   0 ||----||-|||--|---|-||---|-- 28
# query             0 GU----CU-GCACUG--CUCAC-AUCAC 20
#
# target            0 --C-CCCAAAC--UAGCUC--GCGUUA- 20
#                   0 --|-|||---|--|||-|---||-|--- 28
# query             0 AUCGCCC---CCAUAG-U-AAGC-U--G 20
#
# target            0 GAAGUGAA--CC--A-UCUUCGCC-A-- 20
#                   0 ||-|--||--|---|-|||-|----|-- 28
# query             0 GA-G--AAGGC-UUAAUCU-C---UACU 20
#
# target            0 G-ACCUCUAUGACC-GGACU-----C-G- 20
#                   0 --||-||-----||-||--|-----|-|- 29
# query             0 -CAC-UC-----CCAGG--UGGUUUCUGA 20
#
# target            0 --AU--CUGUUGGCAC-CU---AGAUGC- 20
#                   0 --|---|-|--|--||-||---||--|-- 29
# query             0 CCA-GAC-G--G--ACUCUUUCAG--G-A 20
#
# target            0 CAGCGUCGCAGCA--C-A-G-GC-UU--- 20
#                   0 -----|-|--|||--|-|-|-||-|---- 29
# query             0 -----U-G--GCAUACCAUGUGCCU-GAG 20
#
# target            0 --G--G-AAA-C-AGGC-UGGCACCCAG 20
#                   0 --|--|-||--|-|||--||--|----| 28
# query             0 AUGCCGCAA-GCGAGG-AUG--A----G 20
#
# target            0 CAC-UAAGGAAU-C---AAG--CAGAA---- 20
#                   0 ----|--|-|-|-|---|-|--|-|------ 31
# query             0 ---GU--G-A-UUCCUUA-GUUC-G--UCUU 20
#
# target            0 AAU-AACA--GCU--AUAUCGAGA-U--- 20
#                   0 --|-|-----|-|--||||--||--|--- 29
# query             0 --UUA---UUG-UCGAUAU--AG-CUCUA 20
#
# target            0 GCCAUCCUUG-UAGCG----UU-GGC----- 20
#                   0 -|-------|-|||-|----|--|-|----- 31
# query             0 -C-------GGUAG-GAACAU-CG-CAACCG 20
#
# target            0 CAGA-CGUGACGAG-UG-U-AG--UG--- 20
#                   0 --|--|-||-|-|--||-|-|---|---- 29
# query             0 --G-UC-UG-C-A-CUGCUCA-CAU-CAC 20
#
# target            0 UAG-CGGGGGUAUC----AUUC-G-A--C-- 20
#                   0 -|--||-------|----||---|-|--|-- 31
# query             0 -A-UCG-------CCCCCAU--AGUAAGCUG 20
#
# target            0 CUCUUCCGA-AUUAGAG---A-UG----A-- 20
#                   0 -------||-|--||-|---|-|-----|-- 31
# query             0 -------GAGA--AG-GCUUAAU-CUCUACU 20
#
# target            0 GUG-AGGG-UCCACCAAAGA-------CU-- 20
#                   0 ----|----|||-|-|--|--------||-- 31
# query             0 ---CA---CUCC-C-A--G-GUGGUUUCUGA 20
#
# target            0 GGUCUGCCUGAGAAA-G---UCCU------- 20
#                   0 ---|--|---|||---|---||-|------- 31
# query             0 ---C--C---AGA--CGGACUC-UUUCAGGA 20
#
# target            0 ACCGUAUGG--UACAC--G-GACUC---- 20
#                   0 ----|--||--|||-|--|-|-|-|---- 29
# query             0 ----U--GGCAUAC-CAUGUG-C-CUGAG 20
#
# target            0 UAC-GGCGUUCGCUCCUA--C-----UC--- 20
#                   0 -|--|-|---|||----|--|-----|---- 31
# query             0 -A-UG-C---CGC----AAGCGAGGAU-GAG 20
#
# target            0 CG-----CCCCUUAGGGA--CG-CAGUU 20
#                   0 -|-----||--||||-----||-|--|| 28
# query             0 -GUGAUUCC--UUAG---UUCGUC--UU 20
#
# target            0 UGC-AUU-U--A-AGUUGGACG-UCG-- 20
#                   0 |---|||-|--|-|-|---|-|-||--- 28
# query             0 U--UAUUGUCGAUA-U---A-GCUC-UA 20
#
# target            0 AUC---ACG-AAUU-A-CGCAGACCA- 20
#                   0 --|---|-|-||---|-||||-|||-- 27
# query             0 --CGGUA-GGAA--CAUCGCA-ACC-G 20
#
# target            0 AAUGU--GCACCUGA-U-AG-A-CGA- 20
#                   0 ---||--||||-||--|-|--|-|-|- 27
# query             0 ---GUCUGCAC-UG-CUCA-CAUC-AC 20
#
# target            0 GGUCAACUCG-----A-AG-A-GCCUGA 20
#                   0 ----|--|||-----|-||-|-||-||- 28
# query             0 ----A--UCGCCCCCAUAGUAAGC-UG- 20
#
# target            0 GAUAGAUCGACGUGG-U----C-C-AG-- 20
#                   0 ||--||---|-|-|--|----|-|-|--- 29
# query             0 GA--GA---A-G-G-CUUAAUCUCUA-CU 20
#
# target            0 UGUCGACG-CACGCC---UCG-UU----A 20
#                   0 ---|-||--|-|-|----|-|-||----| 29
# query             0 ---C-AC-UC-C-C-AGGU-GGUUUCUGA 20
#
# target            0 AC-A-ACGGCAGGG-UC---CCC-G-AU 20
#                   0 -|-|-||||-|----||---|---|-|- 28
# query             0 -CCAGACGG-A---CUCUUUC--AGGA- 20
#
# target            0 AC-GCG-AUACCAAU-UG---GACAA- 20
#                   0 ---|-|-||||||-|-||---||---- 27
# query             0 --UG-GCAUACCA-UGUGCCUGA---G 20
#
# target            0 AAAAAUAUGUGUCCG---GC-A--A-G-- 20
#                   0 |----|--|---|||---||-|--|-|-- 29
# query             0 A----U--G---CCGCAAGCGAGGAUGAG 20
#
# target            0 GCAG---A-UUC--UAUUGCA-UCCCC-- 20
#                   0 ||-|---|-|-|--|---||--||----- 29
# query             0 GC-GGGGAAU-CCCU---GC-GUC---AA 20
#
# target            0 UU--GUAGGG--UCU-A-CC-GCUCAU-- 20
#                   0 ----|||-----|-|-|-||-||--|--- 29
# query             0 --ACGUA---AAU-UCAACCUGC--A-GC 20
#
# target            0 UC-G-G-UAUGAGA--CGGUCUCG-U 20
#                   0 |--|-|-|-|-|-|--||-|||-|-| 26
# query             0 U-AGUGCU-U-A-AUGCG-UCU-GGU 20
#
# target            0 GUGUUUCUAGCA-GA-G---UA-C-GC- 20
#                   0 -|-|----|-||-|--|---||-|-||- 28
# query             0 -U-U----A-CACG-UGGACUAUCUGCU 20
#
# target            0 CCCCAAAC-U--AGCU-CG-CGUU-A-- 20
#                   0 ||--|----|--||||-|--||---|-- 28
# query             0 CC--A---GUUGAGCUUC-UCG--GACU 20
#
# target            0 G--A---AG-UG-AACCA--UCUUCGCCA 20
#                   0 ---|---||-||-|-|||--||------- 29
# query             0 -CUAUCUAGCUGCA-CCAGGUC------- 20
#
# target            0 GAC--CU-C-UAUGACCGGA-C--UCG 20
#                   0 -||--||-|-|--|-|-|||-|--|-- 27
# query             0 -ACAGCUGCGU--G-C-GGAGCAAU-- 20
#
# target            0 AUCUGUUG--G-CACCUAGAUG--C-- 20
#                   0 -|--||||--|-|-||-||--|--|-- 27
# query             0 -U--GUUGCCGUC-CC-AG--GGGCUA 20
#
# target            0 CAGCGUCGCAGC-ACA-GG----C-U-U- 20
#                   0 -----|-||-||-|---||----|-|-|- 29
# query             0 -----U-GC-GCUA--UGGUUAACCUGUU 20
#
# target            0 GG-----A-A-ACAGGCUGGCACCCAG--- 20
#                   0 -------|-|-||||||---|-----|--- 30
# query             0 --UUUUUAUACACAGGC---C-----GUUC 20
#
# target            0 -CACUAAGG--AAUCAA---GCAG--AA 20
#                   0 -|-----||--||||-----||-|--|| 28
# query             0 GC-----GGGGAAUC--CCUGC-GUCAA 20
#
# target            0 AA--UAACAGCUAU-AU-C--G-AGAU- 20
#                   0 |---|||-|--|-|-|--|--|-||--- 28
# query             0 A-CGUAA-A--U-UCA-ACCUGCAG--C 20
#
# target            0 GCC-A-U-CCUUGUA--GCGU-UGGC- 20
#                   0 ----|-|-|-||--|--||||-|||-- 27
# query             0 ---UAGUGC-UU--AAUGCGUCUGG-U 20
#
# target            0 ---CAGACGUG-ACG-AGUG-UAG-UG 20
#                   0 ---||--||||-||--|-|--|-|-|- 27
# query             0 UUACA--CGUGGAC-UA-U-CU-GCU- 20
#
# target            0 U--AGC--G-GGGG-UAUCAUUCG-AC- 20
#                   0 ---||---|-|----|-||-|-||-||- 28
# query             0 -CCAG-UUGAG---CU-UC-U-CGGACU 20
#
# target            0 CU--CU---U-C-CG-AAUUAGAGAUGA- 20
#                   0 ||--||---|-|-|--|----|-|-|--- 29
# query             0 CUAUCUAGCUGCAC-CA----G-G-U--C 20
#
# target            0 ---G-UGA-GGGU-CC--A-CCAAAGACU 20
#                   0 ---|-||--|--|-|---|-|-||----| 29
# query             0 ACAGCUG-CG--UGC-GGAGC-AA----U 20
#
# target            0 -GGUCUGCCUG----AGAAAGU--CCU- 20
#                   0 -|-|-||||-|----||---|---|-|- 28
# query             0 UG-U-UGCC-GUCCCAG---G-GGC-UA 20
#
# target            0 A--CCG-UAUGGU-ACACGGACUC--- 20
#                   0 ---|-|-||||||-|-||---||---- 27
# query             0 -UGC-GCUAUGGUUA-AC---CU-GUU 20
#
# target            0 U----A--C---GGCGUUCGCUCCUACUC 20
#                   0 |----|--|---|||---||-|--|-|-- 29
# query             0 UUUUUAUACACAGGC---CG-U--U-C-- 20
#
# target            0 CGCCCCUUAGGG-A--C---GCAGUU--- 20
#                   0 -||------|||-|--|---||-||---- 29
# query             0 -GC------GGGGAAUCCCUGC-GU-CAA 20
#
# target            0 UGCA--UUUAAG-UUGG-A-CG-U-C-G- 20
#                   0 ---|--|--||--||---|-|--|-|-|- 29
# query             0 ---ACGU--AA-AUU--CAAC-CUGCAGC 20
#
# target            0 AUCACGAAU--U-AC--GCAGA-CCA---- 20
#                   0 -|-|-|--|--|-|---||-|--|------ 30
# query             0 -U-A-G--UGCUUA-AUGC-G-UC--UGGU 20
#
# target            0 AAUGUG-CACC-UG-A-UAGA-C-GA-- 20
#                   0 --|-|--|||--||-|-||---|-|--- 28
# query             0 --U-U-ACAC-GUGGACUA--UCUG-CU 20
#
# target            0 GGUCAAC--UC-GAAGAGC--CU-G-A-- 20
#                   0 ---|--|--|--||-|--|--||-|-|-- 29
# query             0 ---C--CAGU-UGA-G--CUUCUCGGACU 20
#
# target            0 GA-UAGAUCG-ACG-UGGUC-C-AG--- 20
#                   0 ---||--||--|-|-||--|-|-||--- 28
# query             0 --CUA--UC-UA-GCUG--CACCAGGUC 20
#
# target            0 UGUCGACGCACGCCU-CGUU----A----- 20
#                   0 -----||--|-||-|-|||-----|----- 30
# query             0 -----AC--A-GC-UGCGU-GCGGAGCAAU 20
#
# target            0 ACAAC-G--GCA-GGGUCCCCGA-----U- 20
#                   0 ------|--||--|--||||--|-----|- 30
# query             0 -----UGUUGC-CG--UCCC--AGGGGCUA 20
#
# target            0 AC-GCGA-UACCAAUUGG--ACAA------ 20
#                   0 ---|||--||----|-||--|-|------- 30
# query             0 --UGCG-CUA----U-GGUUA-A-CCUGUU 20
#
# target            0 AAAAAUAUGUGU----C-C-GGCAA-G--- 20
#                   0 -----|-|-|-|----|-|-|||---|--- 30
# query             0 -----U-U-U-UUAUACACAGGC--CGUUC 20
