# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Examining circuit traces and energies
#
# The 2-3 mutations circuits somehow have the largest difference to their reference circuits compared to any other lower / higher mutations. There may be something strange about the circuits themselves causing this or perhaps there is mislabelling - we will try to rule that out here.

# %%
from functools import partial
import os
import sys
import numpy as np
import jax
import jax.numpy as jnp
import diffrax as dfx
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pink_palette = sns.cubehelix_palette(rot=0.5, start=2.7, gamma=1.1)

jax.config.update('jax_platform_name', 'cpu')


if __package__ is None:

    module_path = os.path.abspath(os.path.join('..'))
    sys.path.append(module_path)

    __package__ = os.path.basename(module_path)


from synbio_morpher.utils.data.data_format_tools.manipulate_fasta import load_seq_from_FASTA
from synbio_morpher.utils.common.setup import construct_circuit_from_cfg, prepare_config
from synbio_morpher.utils.evolution.mutation import get_mutation_type_mapping
from synbio_morpher.utils.results.analytics.naming import get_analytics_types_all, get_true_names_analytics, get_true_interaction_cols
from explanations.data_enhancing import enhance_data, proc_info, melt, summ


root_dir = '..'

# %%
og_dir = '../data/generate_seqs_flexible/2023_04_17_205800/'
fn_og = os.path.join(og_dir, 'circuit_stats.csv')
mut_dir = '../data/ensemble_mutation_effect_analysis/2023_05_16_174613/mutation_effect_on_interactions_signal'
fn_mut = '../data/ensemble_mutation_effect_analysis/2023_05_16_174613/summarise_simulation/tabulated_mutation_info.csv'
fn_random_start = '../data/ensemble_mutation_effect_analysis/2023_06_05_164913/summarise_simulation/tabulated_mutation_info.csv'
fn_new = '../data/summarise_simulation/2023_06_28_012658/tabulated_mutation_info.csv'

# %%
data = pd.read_csv(fn_random_start)

# %% [markdown]
# Quickly fix data if needed (this has been fixed in data-generating scripts already)

# %%
# resorted = data[data['mutation_name'] != 'ref_circuit'][['circuit_name', 'mutation_name', 'mutation_num', 'mutation_type', 'mutation_positions']]

# resorted = resorted.sort_values(['circuit_name', 'mutation_name'])
# resorted.index = sorted(resorted.index)
# resorted

# for circuit_name in resorted['circuit_name'].unique():
#     data.loc[(data['circuit_name'] == circuit_name) & (data['mutation_name'] != 'ref_circuit'), 
#              ['mutation_name', 'mutation_num', 'mutation_type', 'mutation_positions']] = resorted[resorted['circuit_name'] == circuit_name][['mutation_name', 'mutation_num', 'mutation_type', 'mutation_positions']]
# data.to_csv('temp_tabulated_mutation_info.csv')

# %%
data, num_group_cols, num_bs_cols, numerical_cols, key_cols, mutation_log, bs_range_cols = proc_info(data)

# %%
dfm = melt(data[data['sample_name'] == 'RNA_0'], num_group_cols, num_bs_cols, numerical_cols, key_cols, mutation_log, bs_range_cols)
# Out:
# /home/wadh6511/Kode/synbio_morpher/explanations/data_enhancing.py:128: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   infom[f'{k}_diffs'] = info.groupby(['circuit_name'])[get_true_interaction_cols2(info, k)].apply(
# /home/wadh6511/Kode/synbio_morpher/explanations/data_enhancing.py:128: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   infom[f'{k}_diffs'] = info.groupby(['circuit_name'])[get_true_interaction_cols2(info, k)].apply(
# /home/wadh6511/Kode/synbio_morpher/explanations/data_enhancing.py:128: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   infom[f'{k}_diffs'] = info.groupby(['circuit_name'])[get_true_interaction_cols2(info, k)].apply(

# %%
data['mutation_species'] = data['mutation_name'].str[:5]

# %% [markdown]
# ## Choose which traces to compare
#
# According to how much they stand out in energies / analytics (covered in other mutation* notebooks). This is all with *unbiased starting circuits*.

# %% [markdown]
# First looking at energy differences

# %%
e_diffs = dfm.groupby(['circuit_name', 'idx'], as_index=False)['energies'].transform(lambda x: x - x.loc[x[dfm['mutation_num'] == 0].index[0]])
e_diffs['mutation_num'] = dfm['mutation_num']
e_diffs['energies_og'] = dfm['energies']
# Out:
# /tmp/ipykernel_89304/248495428.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   e_diffs = dfm.groupby(['circuit_name', 'idx'], as_index=False)['energies'].transform(lambda x: x - x.loc[x[dfm['mutation_num'] == 0].index[0]])

# %%
fig = plt.figure(figsize=(17, 7))
fig.subplots_adjust(hspace=0.325, wspace=0.425)
ax = plt.subplot(1,2,1)
sns.ecdfplot(e_diffs, x='energies', hue='mutation_num', palette='viridis_r', log_scale=[False, True])
plt.xlabel('Energies (kcal)')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('ECDF plot')

ax = plt.subplot(1,2,2)
sns.histplot(e_diffs, x='energies', hue='mutation_num', element='step', palette='viridis_r', fill=False, log_scale=[False, True], bins=100)
plt.xlabel('Energies (kcal)')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Counts of differences')

plt.suptitle('Difference in individual interaction energies\nbetween mutated and reference circuits')
# Out:
# Text(0.5, 0.98, 'Difference in individual interaction energies\nbetween mutated and reference circuits')

# %%
e_diffs[e_diffs['mutation_num'] == 2]['energies'].abs().value_counts()
# Out:
# 0.00     479937
# 4.49        224
# 3.26        208
# 8.14        175
# 6.30        167
#           ...
# 1.06          1
# 4.86          1
# 10.08         1
# 5.04          1
# 5.32          1
# Name: energies, Length: 2858, dtype: int64

# %%
e_diffs[e_diffs['energies'] == 4.49]
# Out:
#          energies  mutation_num  energies_og
# 396322       4.49            15        -8.01
# 999294       4.49            15        -4.23
# 1034961      4.49             1         0.00
# 1034964      4.49             1         0.00
# 1034969      4.49             2         0.00
# ...           ...           ...          ...
# 2783051      4.49            15         0.00
# 2783052      4.49            15         0.00
# 2783053      4.49            15         0.00
# 2783054      4.49            15         0.00
# 2799509      4.49            10        -7.17
#
# [776 rows x 3 columns]

# %% [markdown]
# ## Load circuit sequence

# %%
circuit_name = data['circuit_name'].unique()
path_to_template_circuit = list(data[data['mutation_num'] > 0]['path_to_template_circuit'].unique())
circuit_paths = jax.tree_util.tree_map(lambda x: os.path.join(root_dir, x), path_to_template_circuit)
fastas = jax.tree_util.tree_map(lambda cp: load_seq_from_FASTA(cp, as_type='dict'), circuit_paths)
fasta_d = dict(zip(circuit_name, fastas))
fasta_d
# Out:
# {'toy_circuit_combo0_100192': {'RNA_0': 'CGAGGAACAGUUGCACGAUA',
#   'RNA_1': 'CGAAAAAGAAUUAGGGCGAA',
#   'RNA_2': 'AGUCCCCACUCGUUUUGGCC'},
#  'toy_circuit_combo0_100248': {'RNA_0': 'GAAGAUCUGCAGAAGUUAAA',
#   'RNA_1': 'CACACGCCCGCAUGUCUAAC',
#   'RNA_2': 'CUAGUCUGAUGAGUGAGAGA'},
#  'toy_circuit_combo0_10028': {'RNA_0': 'CCAAUAGCUAUUGGCUAAUC',
#   'RNA_1': 'ACUCACUAGGACGCCUGAUG',
#   'RNA_2': 'GCCCCCGCGUUGUGCCUCCC'},
#  'toy_circuit_combo0_101123': {'RNA_0': 'UGAUGGGAAAUGAACGUGUC',
#   'RNA_1': 'CUGUAAAAACCUUUAGGGCC',
#   'RNA_2': 'AGGCGAGUGGUGCAGCUCAC'},
#  'toy_circuit_combo0_101196': {'RNA_0': 'CAUGAUGGAGUGCGCGGAAA',
#   'RNA_1': 'GCUUCUUUGCUUGCACGCGA',
#   'RNA_2': 'CUCCUAAUUCCGGCGUGGUU'},
#  'toy_circuit_combo0_101549': {'RNA_0': 'UUACUUUAGCAUCCACAAUA',
#   'RNA_1': 'CGAUCGCGAUGUUAUGGACC',
#   'RNA_2': 'CCACCAACAGCUACAGGGCC'},
#  'toy_circuit_combo0_102245': {'RNA_0': 'CAGCAAACUAUAUCGUUAGU',
#   'RNA_1': 'AUGCCUAAAUAGGCCACAUU',
#   'RNA_2': 'CCUCGCGGAGGACCGCAGGU'},
#  'toy_circuit_combo0_102401': {'RNA_0': 'GCGAGUACACCAUCGAGCAU',
#   'RNA_1': 'CCGGCAGACUAAAGGAUUCA',
#   'RNA_2': 'CAGUAAUUAUACCUGGCGUA'},
#  'toy_circuit_combo0_10252': {'RNA_0': 'UACACGCGCAAGACAGCAUG',
#   'RNA_1': 'GGGGCGGUUCGACACAUACC',
#   'RNA_2': 'CCCCCCCGUGUGGUUGACCC'},
#  'toy_circuit_combo0_104029': {'RNA_0': 'CACUUUUUCAUGCAACGUCC',
#   'RNA_1': 'CAGCAAAAUGGCAACUCUAA',
#   'RNA_2': 'UUGUCUCCGCAGAGAGUUAU'},
#  'toy_circuit_combo0_104126': {'RNA_0': 'UUACUAUGGUGAGCUAUUUA',
#   'RNA_1': 'CCAGACUUGACCCUCAGCGU',
#   'RNA_2': 'CGACCGUGUAGGAGGUUGCU'},
#  'toy_circuit_combo0_104853': {'RNA_0': 'AAUUAGAGGUAUGAGUCUAC',
#   'RNA_1': 'AGACACUGGGUUAUGCAAUG',
#   'RNA_2': 'ACAUUAAGUUCUUUAGCGAU'},
#  'toy_circuit_combo0_10505': {'RNA_0': 'AUACCCACCUUCUAUUCAUU',
#   'RNA_1': 'UAGUACUCACAGCGCGUAGG',
#   'RNA_2': 'GAUUAAUGGGCAUGAACAAG'},
#  'toy_circuit_combo0_105086': {'RNA_0': 'UACUGUGGCCGCAGGUGGAG',
#   'RNA_1': 'CAGCAGAUUCUACGUAAGAU',
#   'RNA_2': 'AGGUUACUCGGAGUCACUUU'},
#  'toy_circuit_combo0_105146': {'RNA_0': 'AAUAUCUUGGGUACGUCUCG',
#   'RNA_1': 'UUAAAUCCAAGACAGUUCAU',
#   'RNA_2': 'AUUGGGUACCAUCCGGUCCU'},
#  'toy_circuit_combo0_105420': {'RNA_0': 'AACUACCGGCAGGGACGCGC',
#   'RNA_1': 'UUUCACUCUGAUAUUUUGGC',
#   'RNA_2': 'ACUCUCCGCAUGUAACAUUC'},
#  'toy_circuit_combo0_105634': {'RNA_0': 'AGGUAGUUCUGGACGACAAG',
#   'RNA_1': 'GGUGAGUUGGUAACGUACCC',
#   'RNA_2': 'GCGCGCACGGCCCCAACAAG'},
#  'toy_circuit_combo0_107849': {'RNA_0': 'ACUAAGGAGUGCAGUUCAGA',
#   'RNA_1': 'GUGAUCUAGACAAUCACAAU',
#   'RNA_2': 'UAGGGAUCGGACAAAGUGUC'},
#  'toy_circuit_combo0_10813': {'RNA_0': 'UAUACUAAACAGUAGUACAC',
#   'RNA_1': 'GUCAGGCCUACAAGAUGCAA',
#   'RNA_2': 'CACUCCUCUACACCAACGAA'},
#  'toy_circuit_combo0_108723': {'RNA_0': 'CCAUUUUGCAGACAACGUGU',
#   'RNA_1': 'UGAUGACUAAUGCUUAGUAU',
#   'RNA_2': 'UGAGGCCGGACACGACAUUC'},
#  'toy_circuit_combo0_109237': {'RNA_0': 'UGACGCCAUACGUAAAACUU',
#   'RNA_1': 'AGAAUCCGUACAACGACUGG',
#   'RNA_2': 'CUUGAUCGAUACAGGUCGGU'},
#  'toy_circuit_combo0_110141': {'RNA_0': 'UAUCUAGAUGGUGCCCGGUG',
#   'RNA_1': 'GUUGAACAUGACCUGAGUCU',
#   'RNA_2': 'UCCUCCCCUGUUAGACCAUC'},
#  'toy_circuit_combo0_110249': {'RNA_0': 'AGACGUAUGGUGACUGAGGG',
#   'RNA_1': 'AGGAUUAAUUGCAGCAAUCC',
#   'RNA_2': 'GGUCGCAAACCAGUUGAUUG'},
#  'toy_circuit_combo0_110765': {'RNA_0': 'UCCUAGUAUCGGUGUUGGGG',
#   'RNA_1': 'AGUCACCUGCACUGGAUGUA',
#   'RNA_2': 'UGCUGACGUAAGAGUUAUUA'},
#  'toy_circuit_combo0_111415': {'RNA_0': 'AUUAGGACAGGGGCGUCAGU',
#   'RNA_1': 'GCAAAGCUUUGUACUGCACC',
#   'RNA_2': 'AGUGCGCGCAAGGAGGAUUC'},
#  'toy_circuit_combo0_111514': {'RNA_0': 'GCCGUCAUUCGAUACACAAC',
#   'RNA_1': 'AUCGCGGCCAGCGUCACAUA',
#   'RNA_2': 'AUUCCCAUAAGCGGACUCAC'},
#  'toy_circuit_combo0_111610': {'RNA_0': 'GCAGACGUAAGUCCUCGUUC',
#   'RNA_1': 'GCUAAGAAUACCUCGUCCUA',
#   'RNA_2': 'UUAAACGUACGCACCGAAUC'},
#  'toy_circuit_combo0_111654': {'RNA_0': 'GUAAUAUGGCACCUGAACUU',
#   'RNA_1': 'AAACCCCCCUUUCAGACGAG',
#   'RNA_2': 'AUGUACCAUGUUCAGCUCCU'},
#  'toy_circuit_combo0_111703': {'RNA_0': 'UGUACACUGGCCGAGAGUGA',
#   'RNA_1': 'GUUCAUGGGACCUAUGCACU',
#   'RNA_2': 'CACGAGGUGCGAGAGGACGA'},
#  'toy_circuit_combo0_112416': {'RNA_0': 'CCGCGAGGAUUGAAGAACGU',
#   'RNA_1': 'AAGUUAUGAAUCGCCGCAGA',
#   'RNA_2': 'CAGGACCGCUUUGAACGGGU'},
#  'toy_circuit_combo0_112785': {'RNA_0': 'AAAUUAGGUGAUUGUCAAAU',
#   'RNA_1': 'ACGUGAAAGAGCGUAGGAAA',
#   'RNA_2': 'CCCCCGGACGGCCGGAGUCA'},
#  'toy_circuit_combo0_112924': {'RNA_0': 'GUUUUGUGAUUGGCGAUCUG',
#   'RNA_1': 'CCAAUAGCACUUCGCGUUCA',
#   'RNA_2': 'CCCUCAAGUUACGGCGGCAC'},
#  'toy_circuit_combo0_113131': {'RNA_0': 'GACGGUUCACGCGGGAGGAA',
#   'RNA_1': 'GCGCGUCGCAGAGGUCGAAC',
#   'RNA_2': 'GAAUUUCGAGAGGAUCACUA'},
#  'toy_circuit_combo0_113406': {'RNA_0': 'UCCUAUAAGUAUUGAUAUCU',
#   'RNA_1': 'GCCGCCCGCAGACAGCGUUU',
#   'RNA_2': 'GUGGAACUGGUGUAGUAACA'},
#  'toy_circuit_combo0_113918': {'RNA_0': 'AGUACGUAAAUUUAACAACC',
#   'RNA_1': 'AACUGACACGUCUGAACGAA',
#   'RNA_2': 'AGUCGGAGCCAAUGAUUACU'},
#  'toy_circuit_combo0_114621': {'RNA_0': 'ACUUACGCACCAUGUCACUU',
#   'RNA_1': 'AGAAUAAUGGCGCAGGAUAU',
#   'RNA_2': 'UGGUAUGUAGUAAGUGUCGA'},
#  'toy_circuit_combo0_114945': {'RNA_0': 'AAGUCAUUCAUCGAUGAACU',
#   'RNA_1': 'UCUCAACUCUUUGUGUUAAC',
#   'RNA_2': 'UUCGAGUGUAUAUACAAGGU'},
#  'toy_circuit_combo0_116181': {'RNA_0': 'UCUACUCAAUACCCACAGCU',
#   'RNA_1': 'GAGUCACAUCAAGUUGUGUU',
#   'RNA_2': 'UCGCCCCUUGGCCGACUGUG'},
#  'toy_circuit_combo0_116336': {'RNA_0': 'CUGCAUAAAAUUCCGUCCUU',
#   'RNA_1': 'CUCGGCGCUGUAUGUUAUGU',
#   'RNA_2': 'CCUUGACACCUUUAUUUAAA'},
#  'toy_circuit_combo0_116363': {'RNA_0': 'UUGACCAAUUCAAAGUUUCA',
#   'RNA_1': 'CCUCCAGACGAUGAUAAAAC',
#   'RNA_2': 'GCCCGCAGCCGUUUAGACCU'},
#  'toy_circuit_combo0_116441': {'RNA_0': 'GGAAUAAGUGAGAGAAUACA',
#   'RNA_1': 'GAUGGUUUAUACAUGCGUAA',
#   'RNA_2': 'AACCCGUAGUGAGAUAGCAC'},
#  'toy_circuit_combo0_116587': {'RNA_0': 'UAGCUACCCUUGAAAGCAGA',
#   'RNA_1': 'AGGUUGGGGUAACGUUGAAC',
#   'RNA_2': 'UGCUCUUGUCAUCCUGCCCU'},
#  'toy_circuit_combo0_11682': {'RNA_0': 'CUGAUAUAGUAUACCCACGA',
#   'RNA_1': 'UUAGAUAUUAAAAUACGCUA',
#   'RNA_2': 'CGCAAGGCCAGACAUAAUUA'},
#  'toy_circuit_combo0_11716': {'RNA_0': 'AGAAAGUUUAGCCACCUGCG',
#   'RNA_1': 'CUUACUACUAGCUUUAGAGA',
#   'RNA_2': 'GAGUGACAGUUAACCACACU'},
#  'toy_circuit_combo0_117629': {'RNA_0': 'ACUGUUGCCAGCAUGUAACC',
#   'RNA_1': 'CUUCCUACGUUAUUUGGGUU',
#   'RNA_2': 'GAUAAGCGUCCCUGAUUUGU'},
#  'toy_circuit_combo0_117941': {'RNA_0': 'UACGAGCGAGUAAGUUUCAA',
#   'RNA_1': 'CAGCCAAGCAAUGAAGUUAC',
#   'RNA_2': 'UCCAUCGUGGAUAGGGUUAA'},
#  'toy_circuit_combo0_119242': {'RNA_0': 'AACUUCUGACAUAAAGUGCC',
#   'RNA_1': 'UUCAAUUUGUUGAAGAGUGU',
#   'RNA_2': 'AGGAUUAUGCGCCUCCCUAU'},
#  'toy_circuit_combo0_120450': {'RNA_0': 'UUACAUGACCAAUGGCGACG',
#   'RNA_1': 'AUAGAAUUUGUGUCUGUCAU',
#   'RNA_2': 'UCCUGACUUCUCUUCUACGG'},
#  'toy_circuit_combo0_12077': {'RNA_0': 'GCUUUAUCUUCAUGAGCCUA',
#   'RNA_1': 'UCACACGUCAUAGCGAUAUC',
#   'RNA_2': 'GCACGGAAUGGGGCGCCUGA'},
#  'toy_circuit_combo0_121054': {'RNA_0': 'GUGAUGCAAACUGGCCCAAU',
#   'RNA_1': 'GCAACGAACGGUGAGCUACU',
#   'RNA_2': 'CGCGCGACAGCCGGACCGUA'},
#  'toy_circuit_combo0_122160': {'RNA_0': 'GAUUGUGGUUACAGUGUCCU',
#   'RNA_1': 'CGGGUUAGCGGGACGGGGCU',
#   'RNA_2': 'CGUCUUCACUGUCUAAUUUU'},
#  'toy_circuit_combo0_122162': {'RNA_0': 'GCUAACGCACUACAUUAUCG',
#   'RNA_1': 'AACGUGUGUAUGUUUAGAUC',
#   'RNA_2': 'CUCAUAAGGCCCAGUUUGCA'},
#  'toy_circuit_combo0_122496': {'RNA_0': 'CUUGUAGGACCGUCGUUCCA',
#   'RNA_1': 'AACGGCACACAAACCGGCCA',
#   'RNA_2': 'AAGCAGUAUUCUCUCCUAAC'},
#  'toy_circuit_combo0_123330': {'RNA_0': 'ACGGAUUGUAUUAGGCAUAU',
#   'RNA_1': 'ACCAUAACAGCCCGUAUUUA',
#   'RNA_2': 'GUGCACCUCCCGAUCGGAGU'},
#  'toy_circuit_combo0_12463': {'RNA_0': 'CCCAGACACUUCGCAUCUAA',
#   'RNA_1': 'AGCCUGAUCCAGAAAGGGUU',
#   'RNA_2': 'UGGUGACCCGAUGAGGUAGU'},
#  'toy_circuit_combo0_124676': {'RNA_0': 'ACGUCACAACACUCUGUUCA',
#   'RNA_1': 'ACGGUCGACGCGUACCUAUC',
#   'RNA_2': 'ACCAGUGACGAAUUUGUAUG'},
#  'toy_circuit_combo0_124786': {'RNA_0': 'GCGCUGUCUCAUGUGAUUAG',
#   'RNA_1': 'ACGAGGUUUCGUCUGUUCAU',
#   'RNA_2': 'CACGUUACCAGGUCUAAAGA'},
#  'toy_circuit_combo0_124962': {'RNA_0': 'CCCAUGCUCUCGUAUAAGGU',
#   'RNA_1': 'UUGAGAGGACAGCGCCUAUC',
#   'RNA_2': 'AGGCCCCAUGCCUAAGCUCC'},
#  'toy_circuit_combo0_125035': {'RNA_0': 'GUGCAACUGACGACUUCUUC',
#   'RNA_1': 'CCGCUGCUAACCCGUGGACA',
#   'RNA_2': 'GCCGACAUCUGGGCCCUGUG'},
#  'toy_circuit_combo0_125549': {'RNA_0': 'GGGUCGAGGUGAGCAAGUAG',
#   'RNA_1': 'UGCGCCGACUUAGUAGACUU',
#   'RNA_2': 'CGACACCGUACAACAGAGCU'},
#  'toy_circuit_combo0_126677': {'RNA_0': 'AGAUGAUGUCCACACUCAUA',
#   'RNA_1': 'CUAUCGUACCGAAUGCAUGC',
#   'RNA_2': 'ACAUUGCCUAACCUGCCCAU'},
#  'toy_circuit_combo0_127128': {'RNA_0': 'UCGUAGCGAAUCUGGUGAUC',
#   'RNA_1': 'ACAGUGGAGAUUGUUCGCAG',
#   'RNA_2': 'CCAGGGCCUGGUAAGGCAUU'},
#  'toy_circuit_combo0_127282': {'RNA_0': 'ACUUAUUAUGCUGCGACGGA',
#   'RNA_1': 'UGCGCUCCCCAUCGACUAUG',
#   'RNA_2': 'AUACCCCCUGAGGCGUGCCG'},
#  'toy_circuit_combo0_127496': {'RNA_0': 'GAAUCCACGACGAUUGCCUC',
#   'RNA_1': 'ACUGGCAUAGUUCGUGUACA',
#   'RNA_2': 'CGGAGUUUAAUUGGGAUAAC'},
#  'toy_circuit_combo0_128501': {'RNA_0': 'GAUUGUUUACAAAUAACUUA',
#   'RNA_1': 'ACCUUAACUGGCUGAAGGAC',
#   'RNA_2': 'CAAUUCAUUUUUUUCCAAGC'},
#  'toy_circuit_combo0_129007': {'RNA_0': 'GACACCUACCGUUUCGCCCC',
#   'RNA_1': 'AGCUCUAACACGGGCUACCC',
#   'RNA_2': 'UUUAUGUCCAUCAUUUAUUU'},
#  'toy_circuit_combo0_129726': {'RNA_0': 'CAGGGUUUGGCAAUUACCGA',
#   'RNA_1': 'UGUCCAUCCCCAUGAAGUAC',
#   'RNA_2': 'UGUUGGCAUCAUUAUCGGCU'},
#  'toy_circuit_combo0_130066': {'RNA_0': 'ACGGGCGAGCACUUUAUCAA',
#   'RNA_1': 'AUUUGUAUAUUACCAUAACG',
#   'RNA_2': 'GUGACCGGGAGUCGCGACAC'},
#  'toy_circuit_combo0_130113': {'RNA_0': 'CAUUUUCACUUGAUUAGUCG',
#   'RNA_1': 'AUCGAGGCUGUUUGUGCCGC',
#   'RNA_2': 'CCGAGUCCCGUAAAGCACCG'},
#  'toy_circuit_combo0_130210': {'RNA_0': 'GGUUCCGUUGCGACCCAAGU',
#   'RNA_1': 'ACCUUUUGUGAACGUAGCUG',
#   'RNA_2': 'UCCUGGUACUAAACGGGGGA'},
#  'toy_circuit_combo0_130406': {'RNA_0': 'AGAAAGGGCGCAAUUAAACA',
#   'RNA_1': 'CAUCAGACGCCGGUAGUAGC',
#   'RNA_2': 'AAGAUUUAAUCGCUCUGAAC'},
#  'toy_circuit_combo0_130494': {'RNA_0': 'AAAAUGUUUCGAGUACCAGG',
#   'RNA_1': 'GAAAAGAUCUUCACUGCUUU',
#   'RNA_2': 'CUCCGGGAGUUCCAUCAUAU'},
#  'toy_circuit_combo0_130615': {'RNA_0': 'CCGCUUGCGUGCGGAGAAAG',
#   'RNA_1': 'CGGCUGUCUCAGGUGAUAAC',
#   'RNA_2': 'GAAAGAGGUUCUACGGUGAU'},
#  'toy_circuit_combo0_130620': {'RNA_0': 'CUGUACCGUCUGAGCGAUUA',
#   'RNA_1': 'AUUCCGGACCACGCUGUUGC',
#   'RNA_2': 'CUCUGACUAACUAGGCCAUC'},
#  'toy_circuit_combo0_130865': {'RNA_0': 'ACUUGUACGAUAAGCCCACA',
#   'RNA_1': 'UGUGGCCCAUCGUAUAGUAG',
#   'RNA_2': 'AAACGGAGGCCAAAUUGGGG'},
#  'toy_circuit_combo0_132904': {'RNA_0': 'CGUCAACCGCCAUGCUUCAU',
#   'RNA_1': 'CCAUCAUGCGAACGGGGCAG',
#   'RNA_2': 'GGAGCAGAAGAGCGUCACCG'},
#  'toy_circuit_combo0_133078': {'RNA_0': 'GCCUACGCGCCUGACGUCUC',
#   'RNA_1': 'AGCGAUCAAACUUACGAAGU',
#   'RNA_2': 'GCUUGCUUAAAUCAUAGGCG'},
#  'toy_circuit_combo0_133329': {'RNA_0': 'AGAUGCCACUUAACGCAUUU',
#   'RNA_1': 'GCCCGGGACGGGGUUCUUGC',
#   'RNA_2': 'CCCGGAUUAACUCUUGGAUA'},
#  'toy_circuit_combo0_13395': {'RNA_0': 'UCAACACUGUGGACUUAAGC',
#   'RNA_1': 'AGCUCCCAGUUGAGACACGG',
#   'RNA_2': 'GCUACCUGGUUUUGGACAUG'},
#  'toy_circuit_combo0_134929': {'RNA_0': 'GGUCGCUCAGCAGCUCACGA',
#   'RNA_1': 'AAGCUAGCCGCAGUUUUCAG',
#   'RNA_2': 'GCAGGGGAGAUUUCACGUUC'},
#  'toy_circuit_combo0_136077': {'RNA_0': 'CUCCACCUAUUCGGAGGCUC',
#   'RNA_1': 'UUUGGCUGUGUGGUAGAAUC',
#   'RNA_2': 'ACGAUGACCUCUACGGGUCG'},
#  'toy_circuit_combo0_136117': {'RNA_0': 'AUGUUAGACGUUCCUUUUCU',
#   'RNA_1': 'UGUGUAACGCUGGCUUAACC',
#   'RNA_2': 'GGGGGCGACGCCAGGAUUGG'},
#  'toy_circuit_combo0_136818': {'RNA_0': 'UAGGGGGAUACCAACGAGGA',
#   'RNA_1': 'GGGUCUUGGACGAACAGAGG',
#   'RNA_2': 'GCCUGAAGUUCCCAAAGGCA'},
#  'toy_circuit_combo0_137030': {'RNA_0': 'ACUUGCCUGUAAUCCGUACA',
#   'RNA_1': 'UUCCCUCAGCUAUAUGGGUC',
#   'RNA_2': 'UCGAAUGUCAAAAUGCGUCG'},
#  'toy_circuit_combo0_137135': {'RNA_0': 'GCUCAGACGGUUUCUACUAG',
#   'RNA_1': 'CUUCUGCCACUGCGCUAUUA',
#   'RNA_2': 'CUCUGGUAUACCCCUUCGUA'},
#  'toy_circuit_combo0_137310': {'RNA_0': 'CCUUCACAGGUGCUUCUUGG',
#   'RNA_1': 'CGCUGGUGUAGCCACUCUGU',
#   'RNA_2': 'ACGCGUUUGGGCAAUAACAA'},
#  'toy_circuit_combo0_137320': {'RNA_0': 'CGUUCCACACGUAGAAUCAC',
#   'RNA_1': 'CUGAACGGCCCCUCCUCCAC',
#   'RNA_2': 'AAACUAUACGUUUCACCCGA'},
#  'toy_circuit_combo0_137604': {'RNA_0': 'GUGAGAGUUCCGGUGGCCAC',
#   'RNA_1': 'UGGAGGAGUAAUGGCUACGC',
#   'RNA_2': 'GAAAGUGAAACUAAAGUUCU'},
#  'toy_circuit_combo0_137684': {'RNA_0': 'CGCGCCUAAUAAAAGUUUCU',
#   'RNA_1': 'UAUGGGUGGUUCGGUACCGG',
#   'RNA_2': 'GGUGGGAGUGCGUGUCGUCA'},
#  'toy_circuit_combo0_138438': {'RNA_0': 'GCAUAAUGCGGUUCUCCUUG',
#   'RNA_1': 'UCCCUUGGCCACAGAGGGAA',
#   'RNA_2': 'CCUAAUGUUCAAACAUUAGC'},
#  'toy_circuit_combo0_138491': {'RNA_0': 'GGUCUUAGCCACAAAUGACA',
#   'RNA_1': 'AGGUCGGUCUUUUCUGGACU',
#   'RNA_2': 'GUUCAUUUCUUCUGUAGAUA'},
#  'toy_circuit_combo0_13945': {'RNA_0': 'CCAUAGGAGAAAAAGGCGCA',
#   'RNA_1': 'UAGCGACAACUGUAGUCGCU',
#   'RNA_2': 'AUGAACGCUCUACUUUCGUG'},
#  'toy_circuit_combo0_139537': {'RNA_0': 'CUUAGUAGGCUGGUAUAAAG',
#   'RNA_1': 'GCUUUGUUAGUCGUGGGAUG',
#   'RNA_2': 'ACUGUUGCACAUCUUAGAAC'},
#  'toy_circuit_combo0_139592': {'RNA_0': 'UGGCAUAAUUCAUGCGGAUG',
#   'RNA_1': 'ACGAAGCGGCCAUCGCUCCA',
#   'RNA_2': 'GACAACAACGAACCUAGCAU'},
#  'toy_circuit_combo0_143394': {'RNA_0': 'AGAUAUUAUGUCUGUGACAG',
#   'RNA_1': 'CGGACUAUGCUCAUUGAGGU',
#   'RNA_2': 'UAGAAAUCAUAUCAGUUUGU'},
#  'toy_circuit_combo0_143503': {'RNA_0': 'UGAUCGCCGCCCACCCUAAG',
#   'RNA_1': 'GAUGCUUCCUCAGGCCUCCU',
#   'RNA_2': 'CAUGGCCGGAGUCACCAAGG'},
#  'toy_circuit_combo0_14353': {'RNA_0': 'UUCAUGUGAGGCGGUUGCGC',
#   'RNA_1': 'CGUGAAGCGAUUACUCAACU',
#   'RNA_2': 'UAUGUUGAUUAAAAAUACCG'},
#  'toy_circuit_combo0_143648': {'RNA_0': 'AAACUGGUGCAACGUGGACA',
#   'RNA_1': 'GGAUGCUGAGCGCACAUUCA',
#   'RNA_2': 'UAUUUUCCAGCCUCGGGUUA'},
#  'toy_circuit_combo0_144189': {'RNA_0': 'UGACAGGCGGGCGAGACUUG',
#   'RNA_1': 'GACGCGGUUGCAACUCGAGA',
#   'RNA_2': 'ACCAAGGACGAGCCUCUGCC'},
#  'toy_circuit_combo0_14509': {'RNA_0': 'GAGGGAUCCUCCCCGUAGUA',
#   'RNA_1': 'GGUAGGGCGGCACUUGCUGA',
#   'RNA_2': 'UUUUCCAGUUAUGUAGUUAC'},
#  'toy_circuit_combo0_145657': {'RNA_0': 'UUUAUGCGAUCCCGAACCGU',
#   'RNA_1': 'ACUUGGGCAAUGAAUGGCUC',
#   'RNA_2': 'UAUACCCGGUUAUACGUCUG'},
#  'toy_circuit_combo0_146715': {'RNA_0': 'AACGCAGUAUAGAGCAAGGU',
#   'RNA_1': 'CUAGGCGAUUAGUCAGGAUA',
#   'RNA_2': 'CCAGGUCGCGAUUCGGACCG'},
#  'toy_circuit_combo0_146786': {'RNA_0': 'CUCGAGCCUGUCAGCUAGUC',
#   'RNA_1': 'CUCGCCGAGCUAUGCACAGG',
#   'RNA_2': 'GUGCAUCUCGCGGCGAGUGC'},
#  'toy_circuit_combo0_146857': {'RNA_0': 'AUCGCAUCUAGGCGGAUCCU',
#   'RNA_1': 'AAGGUCUUCCGACUACCUGC',
#   'RNA_2': 'GUCCCAAAGAAGUUAGCGUA'},
#  'toy_circuit_combo0_147837': {'RNA_0': 'UUUAUGGACGUUGCGGUCUA',
#   'RNA_1': 'UACGACAUGGUGAGUAUGUG',
#   'RNA_2': 'ACAAGCGUGGGGACACACAA'},
#  'toy_circuit_combo0_147868': {'RNA_0': 'GUUUAAUGCUUACAUAACGA',
#   'RNA_1': 'GUUGUUAAUCCAGUCGAAAG',
#   'RNA_2': 'UGAUGCUUUAGUGAUGAUGG'},
#  'toy_circuit_combo0_148085': {'RNA_0': 'CUCUUCUAGGGUGAACAUAC',
#   'RNA_1': 'UCCCGACUACAACUUACGGA',
#   'RNA_2': 'UUGCGCGCAAGCGCACAGGC'},
#  'toy_circuit_combo0_148723': {'RNA_0': 'ACAAGGUGAUGCCCUAAUCA',
#   'RNA_1': 'CCCUGUUGAAGCAUUGCUGA',
#   'RNA_2': 'UGGUAUGUGUCAAAACGUUA'},
#  'toy_circuit_combo0_148846': {'RNA_0': 'CGCCCCCCACGUAUGAGUGA',
#   'RNA_1': 'CGCACGUGGAGGUCCAAACG',
#   'RNA_2': 'AUAGCGGCCUGAUGUGCGAU'},
#  'toy_circuit_combo0_149875': {'RNA_0': 'CUGGACCAUACGGGCGGCCA',
#   'RNA_1': 'UACGCAGACCGCACCAAAAU',
#   'RNA_2': 'GUCGUAACGGCGCACAAAGG'},
#  'toy_circuit_combo0_150455': {'RNA_0': 'CCAAAACUAAUCCGGUAGUU',
#   'RNA_1': 'CCAUCUUUUCUUGAAAAAUG',
#   'RNA_2': 'UCCUGGUCUCAGCACCGUUA'},
#  'toy_circuit_combo0_151512': {'RNA_0': 'CCACAUGGUAUUAUGACUGU',
#   'RNA_1': 'CGCCUAGGUCUACAUUCACU',
#   'RNA_2': 'CGCCGAUUGAACGGGGAUCC'},
#  'toy_circuit_combo0_152136': {'RNA_0': 'AUGUCCGGGAGGUGUACUGU',
#   'RNA_1': 'CCAAACGGCGAUUCCGAAGG',
#   'RNA_2': 'GAUUCUUCUUCACAUUUCAA'},
#  'toy_circuit_combo0_152235': {'RNA_0': 'CGCAUAGCAAGAUAGUUGGA',
#   'RNA_1': 'AAACUCAAUCCCAUGGAAUA',
#   'RNA_2': 'ACCACCCUUAGAACGUUCUU'},
#  'toy_circuit_combo0_15241': {'RNA_0': 'CCACAACAGAUCAACUAACU',
#   'RNA_1': 'UGCUGCCGAUGAGUAUAAGU',
#   'RNA_2': 'UCCGAUAAGCGAAUUACCAC'},
#  'toy_circuit_combo0_152595': {'RNA_0': 'GUGCUGGGCCUAAUUUGCCA',
#   'RNA_1': 'AUCAUUGGCAGUCCGUCCGA',
#   'RNA_2': 'UUGGAGCAACUAUAUCUUGA'},
#  'toy_circuit_combo0_15347': {'RNA_0': 'CUCCGAACAAGCUAAAAUGU',
#   'RNA_1': 'AGCUUUUGUUUGUAACCUAG',
#   'RNA_2': 'UCCGUCGGAUGUAAUCUGCG'},
#  'toy_circuit_combo0_153503': {'RNA_0': 'GUCCGCUGGCCGCCAACCUC',
#   'RNA_1': 'CCCGUCAGAGAGCGAAGCUC',
#   'RNA_2': 'UCCUAGUUGUAACUAACUUC'},
#  'toy_circuit_combo0_153545': {'RNA_0': 'ACUUAGAAGGCCUAAACACC',
#   'RNA_1': 'AGGAAGGCCUAGGUACAUCA',
#   'RNA_2': 'GUUCUGCGCCGUAGCGGUGU'},
#  'toy_circuit_combo0_154332': {'RNA_0': 'AGGUAUCCAACGGGCGGAUC',
#   'RNA_1': 'AAUGACCCUCGGUACAGCUA',
#   'RNA_2': 'GGGCCCGCUCCUUCAAAAUA'},
#  'toy_circuit_combo0_154334': {'RNA_0': 'UUCGGAUGAACACCUCAUUC',
#   'RNA_1': 'GCUCCGGUCACUUUUCCCUU',
#   'RNA_2': 'UGACUAUUGAGCUUCUCGGG'},
#  'toy_circuit_combo0_154597': {'RNA_0': 'UAUUCCAUAGCAAUCGGGCU',
#   'RNA_1': 'CUUCUCUAUACAAAGGACGA',
#   'RNA_2': 'CCUGGUGUUGAUACGGUGCU'},
#  'toy_circuit_combo0_156047': {'RNA_0': 'CAAGGCCCUACCCAGCGAUC',
#   'RNA_1': 'UGUGCAAUUUUGCGGGACAU',
#   'RNA_2': 'GGAAGUAGAAAUCCGCCUCA'},
#  'toy_circuit_combo0_156461': {'RNA_0': 'AUACAAUCAUAUCAGCGUAA',
#   'RNA_1': 'AAGGUAGGAAGUAACGCAGC',
#   'RNA_2': 'UGUACACGGGGACAAUGUAU'},
#  'toy_circuit_combo0_157599': {'RNA_0': 'AUGCAGCCUGCAGAUCACCG',
#   'RNA_1': 'CACAUUCAGUUACGAGAUUG',
#   'RNA_2': 'UACACAAUCUAUAAUUUUAG'},
#  'toy_circuit_combo0_157870': {'RNA_0': 'UCACGAUCCAGUCGUUGCGA',
#   'RNA_1': 'CCGACUAGACCCUAUGGCCA',
#   'RNA_2': 'UUCUGGGCACUUAGGCUCUC'},
#  'toy_circuit_combo0_158451': {'RNA_0': 'GGCGUCCCCUUCCCCCAUCA',
#   'RNA_1': 'UCUCUUUCGAAUCGUACUAG',
#   'RNA_2': 'GUGACAAGGGUAAGCAUCAG'},
#  'toy_circuit_combo0_158608': {'RNA_0': 'ACUGUCAAUCAACUCUAGAG',
#   'RNA_1': 'CGUUUCCGACCAGAGGUUCA',
#   'RNA_2': 'ACCGUGAGGGAUCAGUCCGU'},
#  'toy_circuit_combo0_158690': {'RNA_0': 'GAAAUGAUUGACUCGAGCGU',
#   'RNA_1': 'AAUUCGACGCAGUGUUGUGU',
#   'RNA_2': 'GACGACCGUUCGGAGAAAUG'},
#  'toy_circuit_combo0_159229': {'RNA_0': 'CUUCGGUGGUAAGUGAUACA',
#   'RNA_1': 'GCGGCCCGAACAAACAGCAU',
#   'RNA_2': 'AUGGUGAACCGACUCGCAUU'},
#  'toy_circuit_combo0_159404': {'RNA_0': 'UGUGCCCUCGUUAAGGUAAG',
#   'RNA_1': 'UAGAAACGAAAUUCCAAGAG',
#   'RNA_2': 'UUCUACCAUGAAGAUAUUCG'},
#  'toy_circuit_combo0_159822': {'RNA_0': 'GGCGAAAGACGUUCUCACCA',
#   'RNA_1': 'GAAUGUGCCAUGCUAAGGGC',
#   'RNA_2': 'CGCCCCCGAGACCGUAAGUG'},
#  'toy_circuit_combo0_159980': {'RNA_0': 'UUCUAUACCAGAAGUUUCAU',
#   'RNA_1': 'CAUGAAUAUCCUGUGGCUGG',
#   'RNA_2': 'ACUCAGUAUAAGAGGUGUGG'},
#  'toy_circuit_combo0_160165': {'RNA_0': 'GCUAGGAUCCGGCAACGCUU',
#   'RNA_1': 'CGACGAGUUUCGGGAGUGUC',
#   'RNA_2': 'AAACGUCGCAGGGCGAGAUG'},
#  'toy_circuit_combo0_161017': {'RNA_0': 'CCAGAAGACGAUCGAACCUA',
#   'RNA_1': 'GGACCCGAAAAAAUCAGCUC',
#   'RNA_2': 'CAACUCCGCCCCGAACGCAA'},
#  'toy_circuit_combo0_161315': {'RNA_0': 'GUCUACUGACACACCGGAAC',
#   'RNA_1': 'CUAAAAUUUCUGUCACGUCA',
#   'RNA_2': 'GUACUGCGCUUACCUCCAAU'},
#  'toy_circuit_combo0_162379': {'RNA_0': 'GCCGUACUGACGAGCGGACU',
#   'RNA_1': 'UGAUGGCGCUGACUUGCCUU',
#   'RNA_2': 'CCGCGUCCGAGGCAAUUAAA'},
#  'toy_circuit_combo0_16255': {'RNA_0': 'CUCAAACGGGGGAGGUAGGA',
#   'RNA_1': 'GAAACACCGUGCAGGUCUCU',
#   'RNA_2': 'CUCAGAUUACUUCUGUCGUA'},
#  'toy_circuit_combo0_163480': {'RNA_0': 'AUUCUCUUUUUACACAGCAC',
#   'RNA_1': 'UCACAUUGUGCUAAGAGUCU',
#   'RNA_2': 'GCUCGAUCUUACCAUACGUA'},
#  'toy_circuit_combo0_164499': {'RNA_0': 'CUGCGUGCUCGCCCGGAGCA',
#   'RNA_1': 'CAUCGAGCAAUCCUGACAUU',
#   'RNA_2': 'UCAACUUGACCUGAUACGAU'},
#  'toy_circuit_combo0_165291': {'RNA_0': 'GCCUUGAUCGAUGGCAAUGC',
#   'RNA_1': 'GCUAGGCCUCUCUACCACUG',
#   'RNA_2': 'GAUUCGUGGAUUUCCUUUCC'},
#  'toy_circuit_combo0_165613': {'RNA_0': 'GCUCACCCUUGGUGCCGCUA',
#   'RNA_1': 'ACCUCGCCGUGGGAAAUGUA',
#   'RNA_2': 'GUACCGUUAGAUGCUCUCCA'},
#  'toy_circuit_combo0_166514': {'RNA_0': 'GGCCAUGAGUGGGGGCUCGG',
#   'RNA_1': 'CUCCGGAGUGCCUGAGUAGC',
#   'RNA_2': 'GUGUCUGCCUAUGAUGGGUU'},
#  'toy_circuit_combo0_166557': {'RNA_0': 'AAAAUGCACCCGAAGAUAGA',
#   'RNA_1': 'UUACACGUUCCGUCCCCUUA',
#   'RNA_2': 'GAUCCGUGGUACGAGUCCUA'},
#  'toy_circuit_combo0_166699': {'RNA_0': 'CAUUACCCCAUAGCCGACCA',
#   'RNA_1': 'UACCAAUCCUGAUCCAUGCC',
#   'RNA_2': 'UGCAAUAGGAGAGAACACUG'},
#  'toy_circuit_combo0_167489': {'RNA_0': 'GGUGCUUCCGACCACUAUGA',
#   'RNA_1': 'GUGUGGCUCAUCUAGUUCCA',
#   'RNA_2': 'CGACACCACCCUAACAAUAG'},
#  'toy_circuit_combo0_167582': {'RNA_0': 'ACACAUUGAUAUAGAUAUAG',
#   'RNA_1': 'CCAAUAAAGAGUUUUGUCGA',
#   'RNA_2': 'GCAGAGCCUUUUCAUGCGCG'},
#  'toy_circuit_combo0_167671': {'RNA_0': 'AUGUAAGGUGCUUCUAAGUU',
#   'RNA_1': 'AUUCAUGUGCGGUCACAAAU',
#   'RNA_2': 'UUGAGGCGAACCUUGCUUGA'},
#  'toy_circuit_combo0_167815': {'RNA_0': 'CGGUGAUACGUUUGGAUCUC',
#   'RNA_1': 'GAUGAUGUGUUGAAAUAGCA',
#   'RNA_2': 'ACGCCGUUCAUACGGGCACU'},
#  'toy_circuit_combo0_167953': {'RNA_0': 'ACCUGCGCCCUGCUGACUCA',
#   'RNA_1': 'AUUGCAAGAGUCAGUGGACU',
#   'RNA_2': 'CCGCUUAUAGCCCCCAUUUU'},
#  'toy_circuit_combo0_168189': {'RNA_0': 'CACGCGCUCUCUGGCAGUCU',
#   'RNA_1': 'UUGGACAAAGCGAGUCCUGA',
#   'RNA_2': 'CCUAGAAAUGAAUACUCUAA'},
#  'toy_circuit_combo0_168290': {'RNA_0': 'AAAAGCUACUGCAUGUCCCU',
#   'RNA_1': 'AGAUCAGGUAUUACUGACUG',
#   'RNA_2': 'AUUCGAUUCACAGAUCCAAC'},
#  'toy_circuit_combo0_168953': {'RNA_0': 'AACAUACGACAUCGGAUUUG',
#   'RNA_1': 'GCACAGACAAGGUUAUCGAC',
#   'RNA_2': 'UUUUGCAGGGAAAAGUUAUG'},
#  'toy_circuit_combo0_169547': {'RNA_0': 'CUCACUUGGCGUAGCUACAG',
#   'RNA_1': 'AGUUGCUGAGGCUCACGAUA',
#   'RNA_2': 'UUACCCUAAGAUGGGCUACC'},
#  'toy_circuit_combo0_170362': {'RNA_0': 'AGAACCCGGCGCUGUCGUCG',
#   'RNA_1': 'GCCGAUUUUCAUGUCCCACG',
#   'RNA_2': 'UAUUUCAGGGGAGGAGAAAA'},
#  'toy_circuit_combo0_17082': {'RNA_0': 'ACCAACCCAGACAUGUGCAA',
#   'RNA_1': 'AGGCCAUAAGCUCGUAACAA',
#   'RNA_2': 'CCUUUUGAUUGACUCAAGAU'},
#  'toy_circuit_combo0_170889': {'RNA_0': 'CGUUAUGAAUGGAAGUCAAG',
#   'RNA_1': 'ACUCAUCUCGGUUCAUUUUG',
#   'RNA_2': 'UCCGCAAUCCGCUCAGACGG'},
#  'toy_circuit_combo0_171531': {'RNA_0': 'GUGGGGUUGUAGUUUCGCUG',
#   'RNA_1': 'GCUCAGGAGACUGGAGGAAC',
#   'RNA_2': 'ACUCACUAAGCCAAUUCGGU'},
#  'toy_circuit_combo0_172079': {'RNA_0': 'AUAAGCCUCAUCCUUAUCCG',
#   'RNA_1': 'GGACUUAUAGCGCCCGCGUA',
#   'RNA_2': 'UAUGAAGUGUGAAUCCUACU'},
#  'toy_circuit_combo0_172900': {'RNA_0': 'GUUAUUCGGCGAUGUCACCG',
#   'RNA_1': 'AAAUCAUAAUCUACAAGCCG',
#   'RNA_2': 'AGAACUUGAUAUCGAAUCCU'},
#  'toy_circuit_combo0_173058': {'RNA_0': 'UAGAAGACUGCGCCGCGAUU',
#   'RNA_1': 'UUUGGCAACGGAGUGGUGUA',
#   'RNA_2': 'GUCCGACGGAUUAGUGCAUC'},
#  'toy_circuit_combo0_173433': {'RNA_0': 'AGAUCACAUAAAACAUCGAU',
#   'RNA_1': 'CGACUAUGGAUAAAUUGGAA',
#   'RNA_2': 'UCUUCAAACAUCCGUAGCCG'},
#  'toy_circuit_combo0_174000': {'RNA_0': 'GUCCCCUCCUAACAGCAGAC',
#   'RNA_1': 'UUGAAUCUGAAUCACGGCCG',
#   'RNA_2': 'CCGAGUCCUCGUCAGUGCCG'},
#  'toy_circuit_combo0_174203': {'RNA_0': 'CGCAGUCAGUGUUUAUGAAC',
#   'RNA_1': 'UACUCCGACUACUCUUCGAU',
#   'RNA_2': 'UACAUCUGGCUAGAUAGGGC'},
#  'toy_circuit_combo0_174245': {'RNA_0': 'GGUCGGCGCUGUCGCCACGG',
#   'RNA_1': 'GAUGGCGCGCGCUGCUACUC',
#   'RNA_2': 'AGUAAACUCUGAAUAUAUGC'},
#  'toy_circuit_combo0_174592': {'RNA_0': 'GAAUAAUGUGAGGAUUUGGG',
#   'RNA_1': 'UACUGCGCUAGCCUCGCGUA',
#   'RNA_2': 'AUUAAUACGCUGGUUGUUAU'},
#  'toy_circuit_combo0_174720': {'RNA_0': 'GGACUUCUUGAGGAGAACAC',
#   'RNA_1': 'GGUUCUAAGCCAUCUACUCU',
#   'RNA_2': 'AUAGCCUAGAUUUCUCUAGU'},
#  'toy_circuit_combo0_174732': {'RNA_0': 'GGAAUAGUAGGCCAACUUAA',
#   'RNA_1': 'GCGCCAGUGAGGUAUGUUAG',
#   'RNA_2': 'GGUAGUAUAUACCAAUCUCU'},
#  'toy_circuit_combo0_175142': {'RNA_0': 'AUGGAGAAGGCUGUCACCCC',
#   'RNA_1': 'CAUGUUCGAGUUUUCUUAUU',
#   'RNA_2': 'UCGGUUAUUUGACUUAUUAC'},
#  'toy_circuit_combo0_175504': {'RNA_0': 'GAUGUCCAAAUGGUACAAGG',
#   'RNA_1': 'GAGCGCCCUGGGAAACCUAG',
#   'RNA_2': 'GGAGCACUCGUACCCCCCAA'},
#  'toy_circuit_combo0_175710': {'RNA_0': 'CCAUUCGCUUGAAGAACCGU',
#   'RNA_1': 'GCGAAGGGCGUUGAUGGUUA',
#   'RNA_2': 'GUCGUGGAGGCUUCAUAGGC'},
#  'toy_circuit_combo0_178481': {'RNA_0': 'CUCUUCGAUGAGGUGCUAGG',
#   'RNA_1': 'CCUUAGCUUGCGCAGUCUUU',
#   'RNA_2': 'UGCUAUCCCCGGUCCCAGCC'},
#  'toy_circuit_combo0_178488': {'RNA_0': 'ACGCUCUCUGACCCCCCUCU',
#   'RNA_1': 'GAUUAAAACUUUUUGAAGUU',
#   'RNA_2': 'CCGUAUGGAUUGGAGUCGAC'},
#  'toy_circuit_combo0_178860': {'RNA_0': 'ACGACUAAUAGUGAACCAGU',
#   'RNA_1': 'GCCCUGUCAUCGACACUGAC',
#   'RNA_2': 'AAACGGGGUCUGGAUAGCGG'},
#  'toy_circuit_combo0_179411': {'RNA_0': 'UCUGUGAGGCGGUCAUUUCC',
#   'RNA_1': 'UAAUUAACCAAACAGCAAAG',
#   'RNA_2': 'GUGGGCCCGUUAUGCCCACG'},
#  'toy_circuit_combo0_179416': {'RNA_0': 'CUUCGCUUAGGCACUUCGAA',
#   'RNA_1': 'GCUAGUGAGACCCUACCAUU',
#   'RNA_2': 'UCACUGGCAUCUCUCAUUCG'},
#  'toy_circuit_combo0_180154': {'RNA_0': 'GACACCUCUAUUAAUUUAUU',
#   'RNA_1': 'GAAGUUUAACGCACUAUUCG',
#   'RNA_2': 'GGUUGCCCAUGGCCGCGACC'},
#  'toy_circuit_combo0_180237': {'RNA_0': 'AACGCUACCCAUGCUACCCU',
#   'RNA_1': 'CCAAGAAAUGCUUACCUGCU',
#   'RNA_2': 'GAAACUGCUACUUAGAAUAA'},
#  'toy_circuit_combo0_180285': {'RNA_0': 'AUUACUGAUCUAAGCUCCAU',
#   'RNA_1': 'GUACGGGGAACCCUAGAGGA',
#   'RNA_2': 'ACGCUUAUAAGUUGCUUAAG'},
#  'toy_circuit_combo0_180813': {'RNA_0': 'UCUGCUACUAUAACACUCCC',
#   'RNA_1': 'UCACAUGUCGAACCGCGUCG',
#   'RNA_2': 'GAAAGAUCCUAGCAUUACUG'},
#  'toy_circuit_combo0_182254': {'RNA_0': 'CGAGACGAUAUUACCGUGGC',
#   'RNA_1': 'UGGCAGCGCAGCCGAGGCGG',
#   'RNA_2': 'CUACACACAGGAGAAACACU'},
#  'toy_circuit_combo0_182419': {'RNA_0': 'AGUCAGUAAGGAUGCAACUG',
#   'RNA_1': 'UUUAUUGGCCUGAUGUGCGU',
#   'RNA_2': 'AGCAGCUCUCCGGGGCAAUA'},
#  'toy_circuit_combo0_182865': {'RNA_0': 'GGUACUCAGAAGAUAUCCCC',
#   'RNA_1': 'UGCAUCGCCUAGAUUGGGUG',
#   'RNA_2': 'AGAGCGAGAUCUCACUGCAA'},
#  'toy_circuit_combo0_183277': {'RNA_0': 'ACCGUGUAUUCCCGUAGGCU',
#   'RNA_1': 'ACAUUCUGCCAACAAUCUUA',
#   'RNA_2': 'UCGUCCAAAAAGCCGACUGA'},
#  'toy_circuit_combo0_183376': {'RNA_0': 'UAGUGCGCCAAGCCCCUAAC',
#   'RNA_1': 'GUGUCUGAGUAAGUAUGCUU',
#   'RNA_2': 'CCUUGGUCGAAUAGUGCCUC'},
#  'toy_circuit_combo0_184206': {'RNA_0': 'CCCGGGCAGAGUACUGCGUA',
#   'RNA_1': 'AGAAUUUAUCACGGUCCUAA',
#   'RNA_2': 'AUCUCGUGGGGGGCUGCGGG'},
#  'toy_circuit_combo0_18518': {'RNA_0': 'UAACCGAAAGUACGGGUGCC',
#   'RNA_1': 'UCCGCGGUGGACGAGCAAUG',
#   'RNA_2': 'UAGGAUCGACGGUACAUUUG'},
#  'toy_circuit_combo0_185180': {'RNA_0': 'AGAGUACGGGCCCCAGCACG',
#   'RNA_1': 'UUUUACGGAUUCUCAAAAGC',
#   'RNA_2': 'CGGCGCGUGUGCUGGGAAAC'},
#  'toy_circuit_combo0_185332': {'RNA_0': 'UUCCUAGGCUCGGCUGACCC',
#   'RNA_1': 'UAUCUCAGUUACUCUUAUGU',
#   'RNA_2': 'CCUCGUGUUGAGGGACGUUG'},
#  'toy_circuit_combo0_18598': {'RNA_0': 'CUGGCUCCGUACAAUCUAUU',
#   'RNA_1': 'CUUUAGGCGGAGCGAAAGAC',
#   'RNA_2': 'GGAAGCAAUUAGUACGUCCG'},
#  'toy_circuit_combo0_186353': {'RNA_0': 'CGGAUUUCAAUUGUAUACCC',
#   'RNA_1': 'AACGGACCCAACAGGGCGAC',
#   'RNA_2': 'UAUCUUGUUGGCAUAAUAGC'},
#  'toy_circuit_combo0_186781': {'RNA_0': 'CGUAUCAAAGAGACGUUUAU',
#   'RNA_1': 'GACGAAUCCUUAAGGUAUUU',
#   'RNA_2': 'CCACCAAAUGGAGUGUCCGG'},
#  'toy_circuit_combo0_186942': {'RNA_0': 'UAGAGUAGUAAUGUUAGACA',
#   'RNA_1': 'CCGAAGGUAGGUCAAGGCGC',
#   'RNA_2': 'CGGGAUGGUGAUUUCACAAU'},
#  'toy_circuit_combo0_187094': {'RNA_0': 'CGAGUGGUCGAGCUUACGGA',
#   'RNA_1': 'GAUUACUCAGGAUUGCCUAA',
#   'RNA_2': 'AAGAGUGCGGGCACAUCGGG'},
#  'toy_circuit_combo0_187241': {'RNA_0': 'UCGAGGACCUUGGACAGUCA',
#   'RNA_1': 'UAAACCAAUACGAAGGGACU',
#   'RNA_2': 'ACAAGUGGGUGAUCCCGGAA'},
#  'toy_circuit_combo0_18771': {'RNA_0': 'UUGUGGUACCGUGACCAUUA',
#   'RNA_1': 'GUUAGUGAGGGCGAAGACGG',
#   'RNA_2': 'CUUCCGACGACAGCCUAUAA'},
#  'toy_circuit_combo0_188035': {'RNA_0': 'UAUUGGUUGCUUCGGGUCCC',
#   'RNA_1': 'UCAACCGGCAAUUUAUCCGG',
#   'RNA_2': 'CGGUAUAAGGAUAAACAUUC'},
#  'toy_circuit_combo0_188324': {'RNA_0': 'GCUUAGGGCCGGCCCUCUUU',
#   'RNA_1': 'CCGGCGGUAGUGCCCUACUG',
#   'RNA_2': 'UUGGGAUCGCCCACUAACCA'},
#  'toy_circuit_combo0_188574': {'RNA_0': 'ACAUCGGUACUAGUGUUUUC',
#   'RNA_1': 'GCUCUCCUUAUUCACGCCCA',
#   'RNA_2': 'UAUUAAAGCAGGCAAUAGAC'},
#  'toy_circuit_combo0_188696': {'RNA_0': 'AUCAACACAACAUAUACAUA',
#   'RNA_1': 'GAGACUUCAGCCGCAUAUAG',
#   'RNA_2': 'GCCAGAUCCACUGUGGGAGU'},
#  'toy_circuit_combo0_18951': {'RNA_0': 'GGAUGAGGUUGACAGGGACA',
#   'RNA_1': 'UAGCUUAGGUUACAUGUGAU',
#   'RNA_2': 'GCAGCUACACCUAUGUGGAU'},
#  'toy_circuit_combo0_189623': {'RNA_0': 'GGAAGACGUACAUACCUGUC',
#   'RNA_1': 'AUAACGGACCUCGGGAAGCC',
#   'RNA_2': 'CAGCAUAUACCACUCAUGCG'},
#  'toy_circuit_combo0_189808': {'RNA_0': 'AAUUGAGAUACGACACGCCU',
#   'RNA_1': 'CUAUAUCUGAUACAGGAUGU',
#   'RNA_2': 'UGCAAUGUCAGGUCCCAACC'},
#  'toy_circuit_combo0_190423': {'RNA_0': 'GCCUUGGAUCACGAGAAACA',
#   'RNA_1': 'CAGGGAAUCACCCGGCCUAG',
#   'RNA_2': 'UACCAACAAGCUUUAUUGCG'},
#  'toy_circuit_combo0_191498': {'RNA_0': 'UUACGCCGAUGGUGUUAUCG',
#   'RNA_1': 'UAUAGCCGCGUCAUCAAAGU',
#   'RNA_2': 'UGUCAAAAAUUCGUUCAAGG'},
#  'toy_circuit_combo0_191860': {'RNA_0': 'UAAGUGGGCUCGGGGAUAUG',
#   'RNA_1': 'CAGAUGUCGGCCUAUACGGG',
#   'RNA_2': 'UGUGACGGUCUUAUCAUGUA'},
#  'toy_circuit_combo0_192516': {'RNA_0': 'GUAAAGGCCACAAGAACCGC',
#   'RNA_1': 'CCGCCUGAUUACUAUCCCGC',
#   'RNA_2': 'ACUGCCUCUUCUGUUUCUAU'},
#  'toy_circuit_combo0_192683': {'RNA_0': 'AAAUAGUAACCGCCGACACC',
#   'RNA_1': 'AAGAUUGUAACGACUACGCU',
#   'RNA_2': 'AGGCUAGCUCUCGUCUGUUG'},
#  'toy_circuit_combo0_192946': {'RNA_0': 'CCUAUCUUAUCCUUCUGAGC',
#   'RNA_1': 'GACAAACAAGUAAAUGACGA',
#   'RNA_2': 'AGGAAUCUGGGUUUUCUUAG'},
#  'toy_circuit_combo0_193715': {'RNA_0': 'GUUGACGACCGCACAGUACC',
#   'RNA_1': 'AUGACUCAACAUGGUAUCGG',
#   'RNA_2': 'AAUGGAUUCGGCGGCGGUCC'},
#  'toy_circuit_combo0_194202': {'RNA_0': 'CCCGGAGAUCAGUGACAUAU',
#   'RNA_1': 'AGCUAUCUAGUUUCACAUAG',
#   'RNA_2': 'CGGCACGCGCCCCAUGGUUA'},
#  'toy_circuit_combo0_195497': {'RNA_0': 'UAUAUCGCCUAAGCAGUUUC',
#   'RNA_1': 'AGCAAAACUUUAUGUGUGAC',
#   'RNA_2': 'CGAUCACCCAAACAGGACGG'},
#  'toy_circuit_combo0_195502': {'RNA_0': 'CCGAGAUCACUUGAAACAAC',
#   'RNA_1': 'CUGGUGUGUUGGCAUGCUCU',
#   'RNA_2': 'AUGGCGUCGUGGACUCAUCA'},
#  'toy_circuit_combo0_195616': {'RNA_0': 'GGAUGGGGGUGCCCUACAGA',
#   'RNA_1': 'CAUGUAUGCUUACGACUUUA',
#   'RNA_2': 'GGUUGCAAACCGUACGAAAG'},
#  'toy_circuit_combo0_195716': {'RNA_0': 'UUGCGCCAUGAUACGGAUCU',
#   'RNA_1': 'CCCAGGCGAUUUCUACUACC',
#   'RNA_2': 'UAUUGGUCGUAGAGCGUAGG'},
#  'toy_circuit_combo0_196772': {'RNA_0': 'ACUCAGCUUAGGGAAGGAAU',
#   'RNA_1': 'UAGAGCAGGGUAUACGGGGC',
#   'RNA_2': 'CAGGAGCCCACCUGGUCAAG'},
#  'toy_circuit_combo0_196913': {'RNA_0': 'UUUCAUGCGCGGGAGGCGCU',
#   'RNA_1': 'UCCGUUACGAUUCCUGCAUG',
#   'RNA_2': 'AGGCAUACGUCAUAUUUACC'},
#  'toy_circuit_combo0_197118': {'RNA_0': 'UUGUUCCGAUAUCACUGACU',
#   'RNA_1': 'GAGUAGCUGGGACGCGAAAC',
#   'RNA_2': 'AGUCCUUAUGGUCGAAGCCU'},
#  'toy_circuit_combo0_198031': {'RNA_0': 'AGGUUUGUGGACUCUUCCUG',
#   'RNA_1': 'AAUAAAUGAAACUCCUAUAU',
#   'RNA_2': 'UUUCGCUCACGAAUACCUAC'},
#  'toy_circuit_combo0_198101': {'RNA_0': 'AUGCUUACCUAUGUGAAGCG',
#   'RNA_1': 'UUCUUCUUGCGUGCUAGUUG',
#   'RNA_2': 'AUGAUCCGUCUGCCAUCGCU'},
#  'toy_circuit_combo0_198799': {'RNA_0': 'GCUCGCAGUACUUAGCACGA',
#   'RNA_1': 'GCGUAUUGUAAUAGUGCUCA',
#   'RNA_2': 'CAUUUUUAUCUCUUAUCGUU'},
#  'toy_circuit_combo0_198944': {'RNA_0': 'UGGUAAGAGCUGUUAUGACG',
#   'RNA_1': 'CGGCCACUGAACCUGCCCGG',
#   'RNA_2': 'ACGUACCAGAGAUUCGGGAU'},
#  'toy_circuit_combo0_199112': {'RNA_0': 'CGCGCAUAAAAAGUAUCCAU',
#   'RNA_1': 'ACGGCAAAACGUACUUGAUC',
#   'RNA_2': 'CAAAGUAAACGCGACGCCCG'},
#  'toy_circuit_combo0_199114': {'RNA_0': 'AUCGAAGUUGCAGAAGUUGG',
#   'RNA_1': 'UGCAAAUAGGCGCGCAGGAC',
#   'RNA_2': 'CUUAAGCUAUGGCUCGUUUU'},
#  'toy_circuit_combo0_199239': {'RNA_0': 'AGGCUACUAUGGACACGUUU',
#   'RNA_1': 'UUAUCCAGCCGCGUGCUUGA',
#   'RNA_2': 'CUCCUAGGCCUGACGCAAAC'},
#  'toy_circuit_combo0_199249': {'RNA_0': 'GAUCACGGACGCGUACUAUC',
#   'RNA_1': 'AGUAGCAAAAAGAAUGCAAA',
#   'RNA_2': 'CGUCCGUAAACCAAGCACAC'},
#  'toy_circuit_combo0_199732': {'RNA_0': 'UAGGCGGAGCAAAUGUGUAA',
#   'RNA_1': 'CCCCAGAGAUACGUAAAGGC',
#   'RNA_2': 'UGUACUCCUGUAUCUCUGCC'},
#  'toy_circuit_combo0_200394': {'RNA_0': 'GCUCCCAUUAUAUAAUGAUC',
#   'RNA_1': 'UGAGUGGUCACGGGCGGGAG',
#   'RNA_2': 'GUUAUAAACGCGUGGGUUAU'},
#  'toy_circuit_combo0_201430': {'RNA_0': 'AGCCUAGUUGACACGUCCCG',
#   'RNA_1': 'ACAGCUGCGUAUCCAUCGAC',
#   'RNA_2': 'CGCUGACCGUAUUUAGGAGU'},
#  'toy_circuit_combo0_201953': {'RNA_0': 'AGCCCAACUGGGUUCAUUAA',
#   'RNA_1': 'CCAAUCUCAGGACUUUGGGG',
#   'RNA_2': 'GGAACUGACUAAGACGGGAU'},
#  'toy_circuit_combo0_202362': {'RNA_0': 'UUCUAGUCGCGGACUUCUGA',
#   'RNA_1': 'GAAGUUGCGGUUCUUAUGCU',
#   'RNA_2': 'GCUCACUUACUACUUGGCCU'},
#  'toy_circuit_combo0_202368': {'RNA_0': 'ACCAACUGCCGUCGCUCUAC',
#   'RNA_1': 'AAUUCCCAGUUCUGCCUCCC',
#   'RNA_2': 'AUUGUCACUCGUUAUCGCCC'},
#  'toy_circuit_combo0_202390': {'RNA_0': 'ACAUCCUGGGAUUGAUAACU',
#   'RNA_1': 'CUAGCGACAUCAGAGGCACG',
#   'RNA_2': 'ACUACAUCAAAACCGUUAAA'},
#  'toy_circuit_combo0_202401': {'RNA_0': 'UGACUCCGAUAAGGGGGGCA',
#   'RNA_1': 'AAUACUGCAGCCAUCCAGGA',
#   'RNA_2': 'UUCUACGUACCACAUUUUAG'},
#  'toy_circuit_combo0_203543': {'RNA_0': 'CGCGUUGACUUCCUCCUCGU',
#   'RNA_1': 'GCUGUAGCCCAUCGGCCACG',
#   'RNA_2': 'UCGAACACCACACAUAUAGC'},
#  'toy_circuit_combo0_204132': {'RNA_0': 'CCAGAUUCCCUCUUUCCUGG',
#   'RNA_1': 'CCUCGGGUAUGGAUUUGGAU',
#   'RNA_2': 'AACGAAUAAUCUUAAUAAGA'},
#  'toy_circuit_combo0_204204': {'RNA_0': 'AAUGCCAUGCCCCUCGUAGA',
#   'RNA_1': 'UGGGCAUGCAGGGGUAGGCA',
#   'RNA_2': 'GCUACCGAGUACAUCAGUUC'},
#  'toy_circuit_combo0_204268': {'RNA_0': 'UAUGAAUCAGCAGAGGAGUC',
#   'RNA_1': 'GCUCUAUUGACAGCUAUGUU',
#   'RNA_2': 'UAAUGGCACGAAAGCAGGUG'},
#  'toy_circuit_combo0_204390': {'RNA_0': 'AAAGCACAAUGUCGGCAACU',
#   'RNA_1': 'GUGAUUCUUGGAAACAACCU',
#   'RNA_2': 'UGCAGUACGAUAUACAGAUU'},
#  'toy_circuit_combo0_204491': {'RNA_0': 'CCGGCACGCUCCGCGCAUCC',
#   'RNA_1': 'UGGCUCUCUACCUCUGACCC',
#   'RNA_2': 'GCUUACCGUCUACCCCGAUC'},
#  'toy_circuit_combo0_204828': {'RNA_0': 'AAUCCUCUUCGAAGAGAUCC',
#   'RNA_1': 'GGGUGCUCGUUCGGCCGCUG',
#   'RNA_2': 'GGUAAUGAACAUUACGCGUG'},
#  'toy_circuit_combo0_205108': {'RNA_0': 'AGCCGGGGGAGAGGGUGAUC',
#   'RNA_1': 'GCACAGCCUAUGUGGCUGAG',
#   'RNA_2': 'CGAUGAGCUAAUUCUAGUCU'},
#  'toy_circuit_combo0_206139': {'RNA_0': 'UGAAGAGACGCGACUUUCUC',
#   'RNA_1': 'CGGCAUGUGCAAUGAGCCGG',
#   'RNA_2': 'GACAGCUAGACAUGUAGUCU'},
#  'toy_circuit_combo0_206238': {'RNA_0': 'ACCAGAAACCAACUGGUUCG',
#   'RNA_1': 'AGAAAUCUUACUCAUAGUAC',
#   'RNA_2': 'UUAACCCGCAUUGAAUGGUC'},
#  'toy_circuit_combo0_2072': {'RNA_0': 'AUAGUACGGUUGCGAGCUAC',
#   'RNA_1': 'AGGACUGAUCCGAUGGUAUG',
#   'RNA_2': 'UUCAAAUAUUCCUUGAGAAA'},
#  'toy_circuit_combo0_207899': {'RNA_0': 'UCAUUAAUAUCCACGGGAAU',
#   'RNA_1': 'UUUCUGAGAUUGAGGCAAGU',
#   'RNA_2': 'GCUGUAGGGCGCGCGCCGCC'},
#  'toy_circuit_combo0_208530': {'RNA_0': 'CUUCAUACCGCAUUGGAAAA',
#   'RNA_1': 'CUACCGCGUGACGUCAUUAG',
#   'RNA_2': 'ACAUCAGUUCUCGGUGCAAU'},
#  'toy_circuit_combo0_209145': {'RNA_0': 'CAUCCGCUAGAGAUUGUAGA',
#   'RNA_1': 'AAGACAUGACAGGGCCUACC',
#   'RNA_2': 'AAUUGGGAAACGUUAAUACA'},
#  'toy_circuit_combo0_209479': {'RNA_0': 'UACAUGGCCACCGUGCGCAG',
#   'RNA_1': 'CGGGUCGAGUGAUGCGAAAG',
#   'RNA_2': 'UUUAAAACUGCCCGACAUGG'},
#  'toy_circuit_combo0_209856': {'RNA_0': 'GCUAAUGCCUUCUCUCUACA',
#   'RNA_1': 'ACGGAUGGGGGCUUUUGAUG',
#   'RNA_2': 'CAACAUCACCGAUAGGCUCG'},
#  'toy_circuit_combo0_210572': {'RNA_0': 'GGGGGCAAAUGUCGGGUUAG',
#   'RNA_1': 'AAAGGGACACUGCCACAUCC',
#   'RNA_2': 'GGCCGGAAUACUCUUGCGGA'},
#  'toy_circuit_combo0_210805': {'RNA_0': 'ACCCAGGGCGGCUCGCCUUG',
#   'RNA_1': 'AAAGUAUCACCGAUGUACUC',
#   'RNA_2': 'UUAAUUCAUCGCUUGUUUCG'},
#  'toy_circuit_combo0_21113': {'RNA_0': 'CGCCACACCUGGUUAAUCUU',
#   'RNA_1': 'CCCGGGUAGACUAAGGUUAG',
#   'RNA_2': 'GAAUUUAAAUGGUACAGUCA'},
#  'toy_circuit_combo0_21268': {'RNA_0': 'CACAGAUUACAGCACCGCUC',
#   'RNA_1': 'AUACAGGGUCUCGGUGCAUU',
#   'RNA_2': 'AGGUUCUACCGUCAUUCCAA'},
#  'toy_circuit_combo0_213004': {'RNA_0': 'UUAAACACGAAACACUAACG',
#   'RNA_1': 'UCCGUAUUCCGAUCAGCAUU',
#   'RNA_2': 'ACAAGAUGAGUCCAAGAACA'},
#  'toy_circuit_combo0_213878': {'RNA_0': 'GUGCAUCAAGUAGAACUAUU',
#   'RNA_1': 'GGCUUUUACCGCGAUACAAG',
#   'RNA_2': 'UAUUCUCACCAUAUCCCAUC'},
#  'toy_circuit_combo0_21399': {'RNA_0': 'UUCAGGCCAAGAAAUGGGCA',
#   'RNA_1': 'GGAGAUAAAAAUAAAGUUCA',
#   'RNA_2': 'CCGACCUGGCUUUAUGCCUG'},
#  'toy_circuit_combo0_215365': {'RNA_0': 'GUGCGUUACUCUCGACCCUG',
#   'RNA_1': 'UGUAUUAAGAUCACAUGUCU',
#   'RNA_2': 'AAGUUGAGCUGUAUAGACUU'},
#  'toy_circuit_combo0_216416': {'RNA_0': 'CGAGGCAAUUAAGCAGAGCC',
#   'RNA_1': 'CGCACCCACCAUAAUUCCUG',
#   'RNA_2': 'AUGAAACGAUCAAAAUUCCA'},
#  'toy_circuit_combo0_217514': {'RNA_0': 'UUUACUUAACCGCAUAGUAC',
#   'RNA_1': 'GUGAUCAAACCCAUGUUGCA',
#   'RNA_2': 'UGCGGCCUCCACUCUCACCC'},
#  'toy_circuit_combo0_218186': {'RNA_0': 'CCGACGUGCUAUCGGACAGU',
#   'RNA_1': 'CAGGCUUUAAAGUCGAAGGU',
#   'RNA_2': 'UGCAACGGUGGCCGAUGAUA'},
#  'toy_circuit_combo0_219339': {'RNA_0': 'AGUACAGCUUCCCAGCCGUC',
#   'RNA_1': 'GCUUCUCAGCUAUAGACGGU',
#   'RNA_2': 'ACAGUCUUGUCCCGGACAAA'},
#  'toy_circuit_combo0_219882': {'RNA_0': 'CGCGUACUAAAGGAUAUAGC',
#   'RNA_1': 'UGGACUAAACGAGUUCCAGC',
#   'RNA_2': 'UCCGAUCGCAUAACACUCAG'},
#  'toy_circuit_combo0_220277': {'RNA_0': 'GUCAGAAUGGGCAAUUCGAG',
#   'RNA_1': 'UUACCCUGGUCAUCUCGCGG',
#   'RNA_2': 'AACCCCGUCUGAGUACGAGU'},
#  'toy_circuit_combo0_2205': {'RNA_0': 'UGAUGGGAACUGAAAUCAAG',
#   'RNA_1': 'UAUCUGUAGAACUAUAUGUU',
#   'RNA_2': 'UACAAAGGGCUACAUCCGCU'},
#  'toy_circuit_combo0_22196': {'RNA_0': 'CUAAGUAAGAAGGCCCACCU',
#   'RNA_1': 'GUGGCAGUUUUAUGAUGUAA',
#   'RNA_2': 'ACUCAUUCCGCAUUACAAUC'},
#  'toy_circuit_combo0_222388': {'RNA_0': 'GAUUAUUGGCGUUCAUUUCG',
#   'RNA_1': 'AAAACGCCACUGGAAUAAGU',
#   'RNA_2': 'GUAGCCUUCUACACUGGCUC'},
#  'toy_circuit_combo0_22301': {'RNA_0': 'ACCUCUAUGUCAAGGACGGG',
#   'RNA_1': 'CGAAUAUCCGGCGCUUGACG',
#   'RNA_2': 'AAUUGUCGAAAAAUACGCUA'},
#  'toy_circuit_combo0_223589': {'RNA_0': 'UGCACGGCUCGCUACCACGU',
#   'RNA_1': 'UGUGUCGUAGAGAAUAAUUU',
#   'RNA_2': 'UCACUCAGGCUUCUAUGAUA'},
#  'toy_circuit_combo0_223747': {'RNA_0': 'ACACACCUGCGAGCACCUAC',
#   'RNA_1': 'GAGAUUCGACAGCGUUUGGG',
#   'RNA_2': 'AAGAGACAUCAGAAGUAGUU'},
#  'toy_circuit_combo0_224130': {'RNA_0': 'UAUUCAAGAGUUCCGGCGGG',
#   'RNA_1': 'ACAGACCCAGUGGAGAUUUU',
#   'RNA_2': 'GACGAUCUUAUCAGCAGGAC'},
#  'toy_circuit_combo0_224965': {'RNA_0': 'AGGAGCGCUCGAUGGCCUAC',
#   'RNA_1': 'UGUGACCCCGCACACUCUUG',
#   'RNA_2': 'CAUGGGAGCAUCUAAGCCGG'},
#  'toy_circuit_combo0_22541': {'RNA_0': 'CCUUGUGGAGUGCGAAUUGA',
#   'RNA_1': 'GCCGAAGCAACCGCCGAAUG',
#   'RNA_2': 'GCACAGCUGCACGGCUAGUA'},
#  'toy_circuit_combo0_226727': {'RNA_0': 'AGAUGGUUAUGGGACAGAAC',
#   'RNA_1': 'UAUCUUGAGGCAGACUUGAA',
#   'RNA_2': 'GAGCACGGAUCUGAUGGGAU'},
#  'toy_circuit_combo0_227225': {'RNA_0': 'UUUUUGUAAGAGGGUAGUUC',
#   'RNA_1': 'UGUUUUCGUACUUGCAGCGA',
#   'RNA_2': 'CGAGUCUGCUGUACUUGCAU'},
#  'toy_circuit_combo0_227664': {'RNA_0': 'UGCUGAAUUCGCCUGAGAAU',
#   'RNA_1': 'CUACUACGCUAAUGUCCUGU',
#   'RNA_2': 'UCAAGUGAAACCCAAUAACG'},
#  'toy_circuit_combo0_228355': {'RNA_0': 'GACUGUAUGUCUUGAAUAAG',
#   'RNA_1': 'CGAAGAGAGUUAAGAUCCGG',
#   'RNA_2': 'AAAGCAGCACUUCCACGCCA'},
#  'toy_circuit_combo0_229618': {'RNA_0': 'AAGCACACAAGAAUCGACUG',
#   'RNA_1': 'CUAUGCGGCGUUAUUUAGGU',
#   'RNA_2': 'GGGGGGAGGGGGUGAUUUCU'},
#  'toy_circuit_combo0_229781': {'RNA_0': 'UGGAACACACCACUUUACGU',
#   'RNA_1': 'UCGCUAUUUAGGAAUAGGAG',
#   'RNA_2': 'GCUGUCAUUUUACACCUUUA'},
#  'toy_circuit_combo0_230579': {'RNA_0': 'UGAGAGAGUUGUCAACGAUA',
#   'RNA_1': 'CCCCCGCUGCUAUCCUCGGC',
#   'RNA_2': 'UCACCGUGCGUUCUACAGAG'},
#  'toy_circuit_combo0_230682': {'RNA_0': 'CUGUCAGACCAUAUUCGUCA',
#   'RNA_1': 'UUUGAUCCAAGACCGGACUU',
#   'RNA_2': 'UGCAUUAUGAGCCAUCAAUG'},
#  'toy_circuit_combo0_231162': {'RNA_0': 'UAUUGUCGUUUGCUCGAACG',
#   'RNA_1': 'UAUCAAGUUAAGGUCUUCAU',
#   'RNA_2': 'AGACGGUGAUUCAGUCGGUC'},
#  'toy_circuit_combo0_231592': {'RNA_0': 'CAGUUCACGAAUACUAAGCU',
#   'RNA_1': 'UCCCCUACCAAGCCUUCCUC',
#   'RNA_2': 'AUUUUGUGAAGCAGGUCGAG'},
#  'toy_circuit_combo0_232281': {'RNA_0': 'GUGAAUAAUUAAUUGCAAUA',
#   'RNA_1': 'GAUGCUGCCAUAAUGCCACG',
#   'RNA_2': 'GCGAUGCUUCGGGGAAGACG'},
#  'toy_circuit_combo0_232628': {'RNA_0': 'AAACUUACUUCUUGGGAUGA',
#   'RNA_1': 'GGGCAACAAAUCAGAUAUAA',
#   'RNA_2': 'CCCACGUAACUGACAACUUG'},
#  'toy_circuit_combo0_233292': {'RNA_0': 'CUAAAGCACAGACGAACGAA',
#   'RNA_1': 'CGGAUCGGGCCGAACAAUAC',
#   'RNA_2': 'AUGGUGUAAGAGAGACUGAC'},
#  'toy_circuit_combo0_233766': {'RNA_0': 'CGCACGCCCACAUUGGGGUU',
#   'RNA_1': 'GGUGUCUGCUACACGAGUGG',
#   'RNA_2': 'GUCAGGUAGGCAAUCACUCG'},
#  'toy_circuit_combo0_234244': {'RNA_0': 'UAGAAGGUAACUUUGCUAGG',
#   'RNA_1': 'GUAGUAGAGUACAGAAGAUC',
#   'RNA_2': 'AUGAAGCUCAUUAGUCAGAC'},
#  'toy_circuit_combo0_234679': {'RNA_0': 'CAAAAACGAAUCCACAGUGA',
#   'RNA_1': 'CCAAUCCCACUACAGGCGAA',
#   'RNA_2': 'CCCGAUAGUCCCUACGUAGU'},
#  'toy_circuit_combo0_234761': {'RNA_0': 'GCCAGAUAUAGGGGCUUCGC',
#   'RNA_1': 'UGGCACUCACGCUGAGGGGU',
#   'RNA_2': 'AAUGGCAAUUGCAAAACGGG'},
#  'toy_circuit_combo0_234938': {'RNA_0': 'CGUGUCGCGACUUAAUGGUC',
#   'RNA_1': 'CACCGAACUUACUAUUUUGU',
#   'RNA_2': 'CAUAACCACAGGAUAGGGGA'},
#  'toy_circuit_combo0_235221': {'RNA_0': 'GACGUCAUGUCGGUGGACAG',
#   'RNA_1': 'CAAACGGACCGAGAUACAUC',
#   'RNA_2': 'AGUCUUAUACGGGCCGAUAU'},
#  'toy_circuit_combo0_235246': {'RNA_0': 'ACGCUGUCCACUAACGGAGC',
#   'RNA_1': 'GCACAGCGCUGCACGCUCAC',
#   'RNA_2': 'UGCUUAUUCGUCGGGAUGGC'},
#  'toy_circuit_combo0_235584': {'RNA_0': 'GGUCUUUGUGUGGUCCGGAG',
#   'RNA_1': 'UUCGGAACCUGCUUGGUAAA',
#   'RNA_2': 'GCUACUAGACACUAGGGUCC'},
#  'toy_circuit_combo0_235585': {'RNA_0': 'ACGCACGGUUGAGGGUCCUG',
#   'RNA_1': 'UUGAUCGGACUGAGAACUAC',
#   'RNA_2': 'GUGGAAUGCCCGUGAAUACG'},
#  'toy_circuit_combo0_236099': {'RNA_0': 'GUCCCCCUCAAGCGGGUUAC',
#   'RNA_1': 'CGCAAUUACUGAGCCCAAUA',
#   'RNA_2': 'UUUACACGGUGAACGCCUCU'},
#  'toy_circuit_combo0_236772': {'RNA_0': 'GUAGAAGGAAGAAGAGCAGC',
#   'RNA_1': 'CUCAAGAAUCAUGCCCGACC',
#   'RNA_2': 'UUUGGUAACCCUCCUUUGGG'},
#  'toy_circuit_combo0_238228': {'RNA_0': 'GACUUGGGCUGCGUCCGUUU',
#   'RNA_1': 'GCUCUCAUUGCACGAGCGUA',
#   'RNA_2': 'AGGCCAGAGAGAGUCGUGCC'},
#  'toy_circuit_combo0_238408': {'RNA_0': 'AACGCAAAGGACGAGUGUCA',
#   'RNA_1': 'GCGCAAAACCACUCACGAGC',
#   'RNA_2': 'CACGCCGCCAGUGUUGAAUA'},
#  'toy_circuit_combo0_239141': {'RNA_0': 'GCUUUCAAGGGAUAGCGCCU',
#   'RNA_1': 'GUAUUGAGUUUCACCGCGAU',
#   'RNA_2': 'AGCAUCCCCAUCUACUCGUA'},
#  'toy_circuit_combo0_239293': {'RNA_0': 'AGGAGCAGAAGUCGGAAGCU',
#   'RNA_1': 'GGUGGGUAGCCUUUAGUAAG',
#   'RNA_2': 'AACAACCGCUGAGCCAAGGG'},
#  'toy_circuit_combo0_240353': {'RNA_0': 'GAGACUUGAUUGUAAUGCGA',
#   'RNA_1': 'GCUGAUCCCAGGCCUUCAAU',
#   'RNA_2': 'UUAGCUAUGACCGCAGGGGC'},
#  'toy_circuit_combo0_240900': {'RNA_0': 'ACCCAGUGACCUGACGACAG',
#   'RNA_1': 'GAGGGACGAUCUGGAACUUC',
#   'RNA_2': 'AGCGGCACUGCCAGCCAGAG'},
#  'toy_circuit_combo0_241480': {'RNA_0': 'UUCGGUCGAGUUUCUGCUCC',
#   'RNA_1': 'AGCUGGUCGCAUCGUAGCAU',
#   'RNA_2': 'UAGAUAUGACCUAGCAGGCG'},
#  'toy_circuit_combo0_241590': {'RNA_0': 'ACGACUACCGUGAUCGCGGA',
#   'RNA_1': 'AAGAGAAACGGGCAAAGAAC',
#   'RNA_2': 'GGACAGGAUAUCGGUGUAUU'},
#  'toy_circuit_combo0_242389': {'RNA_0': 'UGCAGAGCACAUAUUCAUCU',
#   'RNA_1': 'AUGAGCGUUGCAUGGGCCUC',
#   'RNA_2': 'AAGCUAAGAAAGUUUUCGAG'},
#  'toy_circuit_combo0_242567': {'RNA_0': 'GUGCGUUCUCGUUAUGUUCG',
#   'RNA_1': 'CCGAUCAUGCGGCUCGGUUG',
#   'RNA_2': 'CCUAUCGUGGCCGGUGCAGC'},
#  'toy_circuit_combo0_243082': {'RNA_0': 'CAGCCCUUUCAGUAACUUAA',
#   'RNA_1': 'UGGUAAUAGAGGUAACUUGC',
#   'RNA_2': 'CUCCUCGAACUAAGCAAACC'},
#  'toy_circuit_combo0_24335': {'RNA_0': 'UAGUUCUACGUCUCCUGCAG',
#   'RNA_1': 'AGCUUGCGAGGCUCGGACUG',
#   'RNA_2': 'CCGACAAAACCGAACAAGAA'},
#  'toy_circuit_combo0_2440': {'RNA_0': 'CGAGCUCAACGACGGUAAAG',
#   'RNA_1': 'GUUCUAACAAUGCUUUGUUC',
#   'RNA_2': 'CCGUCUAGAUACGAUUCGGA'},
#  'toy_circuit_combo0_244283': {'RNA_0': 'UUAGCCCCCAUUCGCGGGUA',
#   'RNA_1': 'UCUCACCCUCGAUAUGCGCU',
#   'RNA_2': 'GAUCAAUAGAGAUACUCCGC'},
#  'toy_circuit_combo0_245431': {'RNA_0': 'UCCUCCUCUUGCGUCCCUCG',
#   'RNA_1': 'UUACGUGCAUCUAGCAAAUA',
#   'RNA_2': 'GUUACCUCUAGAUGACUCGC'},
#  'toy_circuit_combo0_246775': {'RNA_0': 'AAGAACCCGAACACAUUGCC',
#   'RNA_1': 'AAACGUGUUUAUCCGUUUAA',
#   'RNA_2': 'GCCACGCCCGAUUAAGGGGU'},
#  'toy_circuit_combo0_246960': {'RNA_0': 'ACGUGUCCGCCACAGUUAUA',
#   'RNA_1': 'CGCCCUGACACGUAAACGGU',
#   'RNA_2': 'ACGAGAUUAUCACGUCUCAG'},
#  'toy_circuit_combo0_247171': {'RNA_0': 'GGGGAAGAUACAUGAUAUUU',
#   'RNA_1': 'CCAAGCUUAUAUCUAAUGCA',
#   'RNA_2': 'CAAAGAUGCGCGAGGCUCAG'},
#  'toy_circuit_combo0_247459': {'RNA_0': 'GGCACAUACACUCUAUACUU',
#   'RNA_1': 'UUACUUUGCGACCACGGUGU',
#   'RNA_2': 'GUCUAAACGGGCUGCGAGGU'},
#  'toy_circuit_combo0_247707': {'RNA_0': 'GUUGGCGGCCACACAGCAGG',
#   'RNA_1': 'GCUGCAGUUGGAGAAUACGA',
#   'RNA_2': 'CCCUUAAUAGUGCGUCAUAC'},
#  'toy_circuit_combo0_247988': {'RNA_0': 'UUGAGGGAUCUUCCUAUGAU',
#   'RNA_1': 'GUGAUGUUUAGACUAAAGAA',
#   'RNA_2': 'AACGCGAUAGAUUGUAUCGA'},
#  'toy_circuit_combo0_248395': {'RNA_0': 'UUAAUUUAAGGCGCCUCUAC',
#   'RNA_1': 'AUGCAGCCGCAAAUGUCUGC',
#   'RNA_2': 'CCCAAAUAACUAGGUCUGAG'},
#  'toy_circuit_combo0_248546': {'RNA_0': 'GGUUACCACCACACGCCAAC',
#   'RNA_1': 'GAUUAGCUAUACGAGACCCC',
#   'RNA_2': 'AUCAGUCUUCUAAUAGCUUA'},
#  'toy_circuit_combo0_248903': {'RNA_0': 'CGCCGGCCGACGCAUAAGUG',
#   'RNA_1': 'GAGAUUAUAAGCCAGGACCC',
#   'RNA_2': 'CAGUAACAUAUCAUUGGGAG'},
#  'toy_circuit_combo0_249775': {'RNA_0': 'CGUAACCUACACCCGAUUUG',
#   'RNA_1': 'CAUAACGUCGACGCCCACUC',
#   'RNA_2': 'UAGAUAUGAACACUUUUAAG'},
#  'toy_circuit_combo0_249899': {'RNA_0': 'GGUUGGACACAGUCAGGUCC',
#   'RNA_1': 'AGGACUUUUGUAAUCCUAGA',
#   'RNA_2': 'CAUGUGUUACGGCGCACGGA'},
#  'toy_circuit_combo0_24997': {'RNA_0': 'CAUUCCAAACUUUCUAAUUU',
#   'RNA_1': 'GCAGGACUUGCUCUUGUUAA',
#   'RNA_2': 'GACAGAGGAUCUCAUCGAUU'},
#  'toy_circuit_combo0_250804': {'RNA_0': 'AAAGCACAUCUGUUAUCAGG',
#   'RNA_1': 'GAUUCCGGGGAACUUUGGGG',
#   'RNA_2': 'UAUUCGGAAGGUAGGGAGGC'},
#  'toy_circuit_combo0_251205': {'RNA_0': 'AAUUCACACGAGCUUACUGA',
#   'RNA_1': 'AUGUACUGACACUCCGUGCA',
#   'RNA_2': 'GGCCAGGAACAAAGAACUUG'},
#  'toy_circuit_combo0_251969': {'RNA_0': 'GCUCUAAUCUCUAUCUAAGC',
#   'RNA_1': 'AAAACUGACGUCUGCGACAU',
#   'RNA_2': 'CCGGCCUACCAGCGAGGGAU'},
#  'toy_circuit_combo0_251971': {'RNA_0': 'UUCCAUCUACAGACGCGUUC',
#   'RNA_1': 'CAUGACCACUAUACGAUGAC',
#   'RNA_2': 'CGUGAACUAGGUGAUGAUGU'},
#  'toy_circuit_combo0_253003': {'RNA_0': 'GCCAUCAACUGCGAGCCCAC',
#   'RNA_1': 'AGCAUGUAUACUAACGGAUG',
#   'RNA_2': 'GAUGGGGAAGACCUCUACAC'},
#  'toy_circuit_combo0_253714': {'RNA_0': 'AAACUUGGACGGACUAAUAG',
#   'RNA_1': 'GAUCACCUGAUGGGCAGGUA',
#   'RNA_2': 'CCUGAUUUGAACCCUCAUAU'},
#  'toy_circuit_combo0_253764': {'RNA_0': 'UAGUUCAUGUUCCUGUUCCU',
#   'RNA_1': 'CACUGGCUCUACCUACUUGC',
#   'RNA_2': 'CAACCACCGCCGUCGGGGUA'},
#  'toy_circuit_combo0_254747': {'RNA_0': 'CUGUUAUUGGUCUGAGGACA',
#   'RNA_1': 'GUUAGAAUAGCCUUUUGCAG',
#   'RNA_2': 'UUAGGGUUCUGGCUCCGGUU'},
#  'toy_circuit_combo0_255182': {'RNA_0': 'UGGGGACAGGCGCAAUUCGC',
#   'RNA_1': 'GUAAUUACUGACUCGGUAAU',
#   'RNA_2': 'GGCGAGUCACGCCGCAGCGC'},
#  'toy_circuit_combo0_25553': {'RNA_0': 'AGAGUCCCGAUCGGUAGCGU',
#   'RNA_1': 'AGAGAACUAGACCCGUCGCU',
#   'RNA_2': 'UGCGAGGUAAUACAGUACCA'},
#  'toy_circuit_combo0_256118': {'RNA_0': 'GGCUCCGGAUUCCUAAAGCG',
#   'RNA_1': 'CGGAAUGAGUACGUUCGUAC',
#   'RNA_2': 'UGAAGGCAAAUCUAAAUAGA'},
#  'toy_circuit_combo0_256155': {'RNA_0': 'GGCGUCCUGCUUGCAUACUU',
#   'RNA_1': 'AAAUCCUCACGCCGAGUGGA',
#   'RNA_2': 'ACCGUGGAAGUGAUAGUGGA'},
#  'toy_circuit_combo0_256259': {'RNA_0': 'ACUCGUCGCGAUCAUACUGA',
#   'RNA_1': 'UGAGUUUCUGAGCCCCCGAC',
#   'RNA_2': 'UGUUAGUGGUAACGAAGCGG'},
#  'toy_circuit_combo0_256388': {'RNA_0': 'GUGUCCACUCAACCGUGGGC',
#   'RNA_1': 'GCUACAAAAUCAAUCAGGGG',
#   'RNA_2': 'AAGCAAGAAAGGGGUCCAAA'},
#  'toy_circuit_combo0_256718': {'RNA_0': 'UCAUCAACGUGGUAUCUACA',
#   'RNA_1': 'CUUUCGUUUACGCAAUCUGU',
#   'RNA_2': 'UCCGUGGUUAUUGUAUAUAA'},
#  'toy_circuit_combo0_25746': {'RNA_0': 'CGGAGGAAAGCACGAGUGAC',
#   'RNA_1': 'GAAACGGCGGAAACCCUCCG',
#   'RNA_2': 'UUAGUCCGUAGCCAGCACCU'},
#  'toy_circuit_combo0_257511': {'RNA_0': 'CGUAGGGGCCCAGGAACUCG',
#   'RNA_1': 'UCGAUACCGCAAAGCCGAUC',
#   'RNA_2': 'CGUAGCGCAGUUUAACUCCC'},
#  'toy_circuit_combo0_257523': {'RNA_0': 'UCGCGACGUCCGCUGACUGA',
#   'RNA_1': 'UGGCGCACCGCUCCGUAUAA',
#   'RNA_2': 'AAUUUGAACGUACGUAAAGG'},
#  'toy_circuit_combo0_25799': {'RNA_0': 'AGGAUGCAUAGUGUAACACC',
#   'RNA_1': 'GUAGACACUAGAAAAGCGUG',
#   'RNA_2': 'CAGGCACAUCGCUGAUUCCU'},
#  'toy_circuit_combo0_25814': {'RNA_0': 'GACGCUUGAGUGGUUUUCAG',
#   'RNA_1': 'GUUAAAGCGGAUCGCAGAAU',
#   'RNA_2': 'AGAAGAAUAGGGUAUCCUAU'},
#  'toy_circuit_combo0_258984': {'RNA_0': 'ACCACAUGGUGGGAUUUAUC',
#   'RNA_1': 'GAUACAAGCCCUCGAGCAGA',
#   'RNA_2': 'CGUUCCGGUUCAUCAUCGUA'},
#  'toy_circuit_combo0_259141': {'RNA_0': 'UGCAGCGUAUCUCUAAUAGU',
#   'RNA_1': 'CUGGCCUAUUGUUAGGACGC',
#   'RNA_2': 'GCUGACCAGCUGGUUUCAGG'},
#  'toy_circuit_combo0_259336': {'RNA_0': 'AUAAUCAAGGAGCUCCAGCA',
#   'RNA_1': 'CCGUCUAGGACGGACAGCGU',
#   'RNA_2': 'CUCGUUUCAUUUCUACUUGG'},
#  'toy_circuit_combo0_25934': {'RNA_0': 'CGUCCGACUGAGACCUUGAA',
#   'RNA_1': 'CGCACUAUGUGUAAGAGAUG',
#   'RNA_2': 'GUCGGAUAACGAUAAGCUGA'},
#  'toy_circuit_combo0_259341': {'RNA_0': 'CUGAAGUUCCCGACCUUAUC',
#   'RNA_1': 'CUGGGACUAACACUGGGGAC',
#   'RNA_2': 'ACUGAGAUCUAUUGAAUCAG'},
#  'toy_circuit_combo0_25960': {'RNA_0': 'AUAUUUGCUCUUGACCGCGC',
#   'RNA_1': 'GCCCUUAUUCGUUAUGGCAC',
#   'RNA_2': 'AUGCUGUGUUUCUGCAAUAU'},
#  'toy_circuit_combo0_259650': {'RNA_0': 'GCCUCACGGACACCCAGAUC',
#   'RNA_1': 'CUGAGGAGUCACCCCGUGGG',
#   'RNA_2': 'UCGUCUCGUCGAAGCCUCUU'},
#  'toy_circuit_combo0_259656': {'RNA_0': 'GGUCUCGAAAUGAAUUGGUG',
#   'RNA_1': 'UCAUAGAUACAAAGGGUGAG',
#   'RNA_2': 'UGUAUUCACUCAGGAGAUCA'},
#  'toy_circuit_combo0_259718': {'RNA_0': 'GACACAGUAGUGGAUUUGUU',
#   'RNA_1': 'GGCACCGUAGAGCGGCCUCC',
#   'RNA_2': 'CUCCAGAAUAAAACUACGUU'},
#  'toy_circuit_combo0_259751': {'RNA_0': 'CCGUAGGGUGAAUUAGGGUG',
#   'RNA_1': 'UUAGCCUUGCUGGACGCUGU',
#   'RNA_2': 'AAUAAGUGCUCGUCUGUCAG'},
#  'toy_circuit_combo0_260077': {'RNA_0': 'GGUGCAGUGUAGGCAGUAUU',
#   'RNA_1': 'GGCGCUUCCUGAGCAAAAAC',
#   'RNA_2': 'UACUAGAGCUCAAAGUAUCC'},
#  'toy_circuit_combo0_261023': {'RNA_0': 'UGUCCGUUACAAUACAGACG',
#   'RNA_1': 'CGCUCGUAUUCUGUUAGAAC',
# ...
#   'RNA_1': 'UUGUCCGUAUAGGCAAAAUG',
#   'RNA_2': 'AUACUCACAAGAGAUUUGCG'},
#  'toy_circuit_combo0_509841': {'RNA_0': 'UUAGGCGACUGACUAAAAAU',
#   'RNA_1': 'CCUUUCUCUGGGGAUGGAAA',
#   'RNA_2': 'UGCCAACUAGUUACGUGGGG'},
#  'toy_circuit_combo0_51066': {'RNA_0': 'GAUAUGCCCCCUUCUCAUAG',
#   'RNA_1': 'CGUCCACUUGUUAAUACGAU',
#   'RNA_2': 'UACGGACUCAUUACACCCGC'},
#  'toy_circuit_combo0_510676': {'RNA_0': 'GAUCUGUAUAACAUGCCACA',
#   'RNA_1': 'CAGGCACUGGCCAUGUAGAA',
#   'RNA_2': 'GCGGCCAUCUACCUUGAUUA'},
#  'toy_circuit_combo0_510698': {'RNA_0': 'AUGCGUUGCGUCCAUUAUUC',
#   'RNA_1': 'UUGUAUCAAUUCAUCGAGGG',
#   'RNA_2': 'AUCGCACAGCGACAGAUCUC'},
#  'toy_circuit_combo0_51135': {'RNA_0': 'GGGUGACUUACAACUGACAU',
#   'RNA_1': 'CCGGACGGGAUGGAGCUGAC',
#   'RNA_2': 'CUAGGAUUCUGUAACUAUCC'},
#  'toy_circuit_combo0_511554': {'RNA_0': 'UAAAAGUUGUGGCCACACUC',
#   'RNA_1': 'UUCCUACUGUUGGGUUCACG',
#   'RNA_2': 'CUGGCAAGUUGGUGUGCGCG'},
#  'toy_circuit_combo0_511741': {'RNA_0': 'GUGAUUUGUAACCGACUGCU',
#   'RNA_1': 'GGCUCCAAUAGAUUAUGCGC',
#   'RNA_2': 'ACGGCUGGCAUGUAGGGCGA'},
#  'toy_circuit_combo0_511892': {'RNA_0': 'CACACGGGCAAUACAGCUAC',
#   'RNA_1': 'AACAGGCGUCGAGUAGUCUU',
#   'RNA_2': 'GCGCGGCUCAAGCUAAGGGA'},
#  'toy_circuit_combo0_511990': {'RNA_0': 'GAAAGUGUAUAAUAGUUACG',
#   'RNA_1': 'AUUAAGCGCUAUAAACAGCU',
#   'RNA_2': 'UAGGUCUCAUUGCCCGUUGG'},
#  'toy_circuit_combo0_512287': {'RNA_0': 'ACAUACGUAUUAAAUUAGCC',
#   'RNA_1': 'UUCAAUCGAGAAUAUCGCCU',
#   'RNA_2': 'CGUCGAACAAGACGAUAUAU'},
#  'toy_circuit_combo0_512946': {'RNA_0': 'ACGUUUAUUUACGGUCCUCU',
#   'RNA_1': 'GAGCCAAUGGUCGAAUAGGC',
#   'RNA_2': 'ACCCAGCGAUCCGUUUUAAU'},
#  'toy_circuit_combo0_513388': {'RNA_0': 'CGUACUGAAGCGCUGCCCCG',
#   'RNA_1': 'UGCCUUCUACUCCACUCUAG',
#   'RNA_2': 'ACGCUCCGAACGGGGCAUGC'},
#  'toy_circuit_combo0_513477': {'RNA_0': 'UCCUGCAGCCCCUAGGGUUU',
#   'RNA_1': 'CCAGGCCCUAUAAGGUCCAC',
#   'RNA_2': 'AGGUUGGACGAUUCCGACCG'},
#  'toy_circuit_combo0_513719': {'RNA_0': 'ACGAUAAUACGGGGCUACAU',
#   'RNA_1': 'CGCUACCCAGUGCCCGUAAG',
#   'RNA_2': 'GGCGUACGAGAAGGGCGGGA'},
#  'toy_circuit_combo0_513798': {'RNA_0': 'AGCUGUACCUAUAAUUAGUC',
#   'RNA_1': 'CCCAAUGGCGUCACGGACUA',
#   'RNA_2': 'UGCUUGACGGUCACGAAAAG'},
#  'toy_circuit_combo0_513976': {'RNA_0': 'AGAUUUGUGUGUUAUCUGAG',
#   'RNA_1': 'CGAGCAGGUACGCCUGACGA',
#   'RNA_2': 'AGCAAACAUCACGACGUCCC'},
#  'toy_circuit_combo0_514356': {'RNA_0': 'ACACUGGUCCCAUCUUAUGC',
#   'RNA_1': 'UCCCAACCACGGAGGCCGCG',
#   'RNA_2': 'GUUAUCGUGGUCUGCUAACU'},
#  'toy_circuit_combo0_51470': {'RNA_0': 'AGUCCGACCGCACAUAGACG',
#   'RNA_1': 'GCAACCGGUGAUACUUACGA',
#   'RNA_2': 'GUGUACCACACAAUAUGAGG'},
#  'toy_circuit_combo0_516157': {'RNA_0': 'UUCUGUCCAUGGUUCAUGCG',
#   'RNA_1': 'AGCUUACCAGCAUUACUCUA',
#   'RNA_2': 'GGGCUUCCAGUUGUAGUGCG'},
#  'toy_circuit_combo0_51626': {'RNA_0': 'UUGAUCAGCCGUGUUACAUG',
#   'RNA_1': 'CGAUGCUUGGAUCUUGGCAU',
#   'RNA_2': 'GCGUCUGCUGUCUAGGAUUC'},
#  'toy_circuit_combo0_516588': {'RNA_0': 'CGCGUUUGAAGACAUUAUAU',
#   'RNA_1': 'UAGUUACGGCGAGCGUAGCA',
#   'RNA_2': 'ACAUGGGACAUGUUCCUCGC'},
#  'toy_circuit_combo0_517278': {'RNA_0': 'CAUUUGCACACAUCCUUAAC',
#   'RNA_1': 'GUGUUACGGGCAUCCUAAAA',
#   'RNA_2': 'GUCACCUCUGCUUGCUUGGA'},
#  'toy_circuit_combo0_517560': {'RNA_0': 'UGGCAGCUACAUAUCAGGUC',
#   'RNA_1': 'UCCUUCACCUGGCGCAUGAC',
#   'RNA_2': 'AUCUGGUCAGUCCCUUUCGU'},
#  'toy_circuit_combo0_517596': {'RNA_0': 'UGAGAAUGUGAUGGGUGGCG',
#   'RNA_1': 'AAAAUAAGUAUUACUUGUAG',
#   'RNA_2': 'UCAGUAAGAUGCGACCAAGU'},
#  'toy_circuit_combo0_518949': {'RNA_0': 'ACUGUUGGCAUGAGCUAUUU',
#   'RNA_1': 'UGGUUGGUGGGUUAUGGGCU',
#   'RNA_2': 'CGUAAUAGCAUCUGCCAGUG'},
#  'toy_circuit_combo0_519039': {'RNA_0': 'GUAGGACCAUUGUCGCUGCG',
#   'RNA_1': 'GUCCCCAAGAGGCGGCUAGC',
#   'RNA_2': 'UAUUAUACGGCCAGCCUACC'},
#  'toy_circuit_combo0_519372': {'RNA_0': 'AGUGAAGGUGUGCGCAAGUG',
#   'RNA_1': 'AGCGCCCAGCGCCUACCAGU',
#   'RNA_2': 'GUAUGAUUUUCACAAACAUG'},
#  'toy_circuit_combo0_519579': {'RNA_0': 'UUGGAAAAGACGAUACAGAU',
#   'RNA_1': 'CUCCUUCCGCCAACAUCAGC',
#   'RNA_2': 'GCUAGACGGUCGUCGAACGG'},
#  'toy_circuit_combo0_520138': {'RNA_0': 'AGUAGUAUUCCCUCCGCACG',
#   'RNA_1': 'AUGAGCUCAAUCCGACAGAA',
#   'RNA_2': 'UAUAACCGCAGAAUAAAGCU'},
#  'toy_circuit_combo0_521281': {'RNA_0': 'GGAGACGCAGUUCGGAAGUA',
#   'RNA_1': 'UUAAGCAUAGUCGGACCCAU',
#   'RNA_2': 'UCGGUACCCAGGCCUCGCGU'},
#  'toy_circuit_combo0_521989': {'RNA_0': 'AAGUAAUUGCCAGGGGCGUG',
#   'RNA_1': 'CAAACAGCAAGUGCAGGCGC',
#   'RNA_2': 'GCUCGCCAAGCUAUGGAGAA'},
#  'toy_circuit_combo0_522979': {'RNA_0': 'GUCUCUAAGCCCUCGGGAAG',
#   'RNA_1': 'AGAAUUGCGUUUAGCUCUAC',
#   'RNA_2': 'AUGAGGUAUAUUCUGUCUGC'},
#  'toy_circuit_combo0_523458': {'RNA_0': 'CUGUUGUUCGGCCGCGGUGA',
#   'RNA_1': 'GACACAGUACUCUAGAGUUC',
#   'RNA_2': 'GAAACGCGAGUUAGAAGGUA'},
#  'toy_circuit_combo0_523486': {'RNA_0': 'CCGACUGACUCCAAACUGGA',
#   'RNA_1': 'GCUCCCGUCGCUGAACAACG',
#   'RNA_2': 'CCAUUUAGUCGAUCUAUUAG'},
#  'toy_circuit_combo0_523543': {'RNA_0': 'AAGCCUGGCCAAGACAAGUA',
#   'RNA_1': 'CCCGUGACACGGCGAGUGCG',
#   'RNA_2': 'CUAUACGGAUGUCAGCGUAC'},
#  'toy_circuit_combo0_523915': {'RNA_0': 'CAUUCUCCAUGUCGUGUAGC',
#   'RNA_1': 'AGGUGCCUCAGUGUUAGAGA',
#   'RNA_2': 'GAGAGCGGAUUGUCCCCAAG'},
#  'toy_circuit_combo0_52404': {'RNA_0': 'UCCUAGCCAUGAGACAAUCA',
#   'RNA_1': 'CCCUAUAACGAGUUGAGAUC',
#   'RNA_2': 'UCUGUUGCAACGUCGAUCAU'},
#  'toy_circuit_combo0_524192': {'RNA_0': 'CGCCAACGGCUUCGGUACCU',
#   'RNA_1': 'AGGCUGGCCGCGUUCUCGGG',
#   'RNA_2': 'AGAUCAAUAUUUCGUCGAAG'},
#  'toy_circuit_combo0_525547': {'RNA_0': 'GCACUUUACGAGUACUGGUC',
#   'RNA_1': 'UUGAUUGUGAACACGCUAUC',
#   'RNA_2': 'UUAUCGACUGGCGGACAAGA'},
#  'toy_circuit_combo0_525688': {'RNA_0': 'UAGUAGUUUACCUAUUAUGG',
#   'RNA_1': 'CCGGCGCUGACCCUGAAGGU',
#   'RNA_2': 'CGUAGACCAUAAUGGUAUGA'},
#  'toy_circuit_combo0_525990': {'RNA_0': 'CGAUUUCAGUGCCGGCUCAG',
#   'RNA_1': 'CUCUGAUUGUAUACGUAUAC',
#   'RNA_2': 'UGCAAGCUUUACUGUUUUAC'},
#  'toy_circuit_combo0_526220': {'RNA_0': 'AGACUGGAGUAUGGACGGCG',
#   'RNA_1': 'AACAAAGUAACCUCUGCUUA',
#   'RNA_2': 'GACCGCUGGGAAGUCCAUGC'},
#  'toy_circuit_combo0_526322': {'RNA_0': 'CUACCAGCUAAUCCUCACUU',
#   'RNA_1': 'CCCUCUGACUUCAACGGAAU',
#   'RNA_2': 'GAGGAGGCCUCCAACCGGAG'},
#  'toy_circuit_combo0_526497': {'RNA_0': 'ACUGCAUAACUUCCUUAAUU',
#   'RNA_1': 'ACCUUGGUCAAAGCAGAACG',
#   'RNA_2': 'GUGCAUCAUGCCUUGGCCCU'},
#  'toy_circuit_combo0_526601': {'RNA_0': 'UUAGAUAGACAUACAAGAGU',
#   'RNA_1': 'AAGUGAGGCCUAUAUAUACU',
#   'RNA_2': 'GCGAAAAUUACGUAAAUAAU'},
#  'toy_circuit_combo0_526725': {'RNA_0': 'GCAAGAGCACGGGAUCACAA',
#   'RNA_1': 'AACGCGUGCCCGAGCUUGUA',
#   'RNA_2': 'GAUUAGUACUGACACAAGAC'},
#  'toy_circuit_combo0_526896': {'RNA_0': 'GUAAGUCGUGUUGGGGGGCG',
#   'RNA_1': 'GUCGACUACCAUUGAAGAGU',
#   'RNA_2': 'GGCGCCUACUGCGGUUUGUC'},
#  'toy_circuit_combo0_527291': {'RNA_0': 'GUGAGCCCUGCCUUCGCACU',
#   'RNA_1': 'UUCAUCCAGACUGUUGUGCA',
#   'RNA_2': 'UUAUGGCUUCACACGGAAUC'},
#  'toy_circuit_combo0_527338': {'RNA_0': 'UAGGACACACGUUCACGUAU',
#   'RNA_1': 'CAGCGCUUCUACCUUAAAGG',
#   'RNA_2': 'GAGGCAUAUAAAUUGGCGAC'},
#  'toy_circuit_combo0_527563': {'RNA_0': 'AUAUCGCUUCAAGCUGCGAU',
#   'RNA_1': 'GAGAAACGCCAUAUUCUAUU',
#   'RNA_2': 'AACUACGUAUACUUCGUAAU'},
#  'toy_circuit_combo0_528942': {'RNA_0': 'GGGACUCAUGGGUACGCACG',
#   'RNA_1': 'CCACUGUAAUGCACCACUCU',
#   'RNA_2': 'GUUCCAUCGUAGCUUUGCAU'},
#  'toy_circuit_combo0_529485': {'RNA_0': 'AUUCAAGGAAUAGCGGUCUA',
#   'RNA_1': 'UACAAUAUUACGGGUAAGCC',
#   'RNA_2': 'UUUUUACCUGUUGUAUAGGA'},
#  'toy_circuit_combo0_529527': {'RNA_0': 'ACCAUGUUCAGCGAGUUACC',
#   'RNA_1': 'CGCAAGAAGCCCGGCCCCAG',
#   'RNA_2': 'GUGAUCGAAAGUACGGGGAA'},
#  'toy_circuit_combo0_529975': {'RNA_0': 'UCAGCCCCAGCAUACCCGAG',
#   'RNA_1': 'UCAUGAUUUGCCGGAACAGG',
#   'RNA_2': 'CCUACUGCUCGAGUAAGUCA'},
#  'toy_circuit_combo0_530409': {'RNA_0': 'CGUAUUCUGUUAAUCUUACU',
#   'RNA_1': 'GUAAGUGCAUACUCUAGGGG',
#   'RNA_2': 'UCGUCCGUCAUAUUCAGCGC'},
#  'toy_circuit_combo0_530658': {'RNA_0': 'GCCAGCUAGUACCCUUCGCA',
#   'RNA_1': 'GUCCCGCCUCCUGUUCAACU',
#   'RNA_2': 'ACCGCUAUACACCCCUUGUA'},
#  'toy_circuit_combo0_531061': {'RNA_0': 'AUAUAUGGAUCUCCGCGGGU',
#   'RNA_1': 'GAUAUCUCGAGAAUAAACUC',
#   'RNA_2': 'UCCGGACAACGAAUAAAGAG'},
#  'toy_circuit_combo0_531336': {'RNA_0': 'CGUUAUACUGUCUUGAGGAA',
#   'RNA_1': 'CCACACGUGCUGGUCCUUUC',
#   'RNA_2': 'AAGACAUCGCUUUCUGAGAC'},
#  'toy_circuit_combo0_531745': {'RNA_0': 'GCCGGCAUAGUUGUCACUGC',
#   'RNA_1': 'AGGUCGCUAUAUGUCGAUCU',
#   'RNA_2': 'AAUUCUUCGCCUAGUCCCGU'},
#  'toy_circuit_combo0_531773': {'RNA_0': 'GUCGCUAAUUCCAAAGUUGG',
#   'RNA_1': 'CGCGUCUGAAUUCGCACAGA',
#   'RNA_2': 'GCUCAGCCGCAAAUCGACCU'},
#  'toy_circuit_combo0_532005': {'RNA_0': 'CGAUCCCCACCAGCAUAUGC',
#   'RNA_1': 'CUGGGACAUUUCUCAGCAGC',
#   'RNA_2': 'GUAGACGGGCACGCCGGAAU'},
#  'toy_circuit_combo0_53318': {'RNA_0': 'CGUCGAUAGGAGCUCGCCUA',
#   'RNA_1': 'CAGCCCAAUGGGCGGAAACU',
#   'RNA_2': 'ACGUUCCACGUCCCGGGGGC'},
#  'toy_circuit_combo0_534203': {'RNA_0': 'UGCAGUUCCGCGCGGUAAGG',
#   'RNA_1': 'UCACGCCCGAGCCCCUCACA',
#   'RNA_2': 'CGAACCACUCGACCAAGCUC'},
#  'toy_circuit_combo0_535710': {'RNA_0': 'UGGGGGGUGACUAAAGUUCC',
#   'RNA_1': 'CGAAUCGCUUAUACCCUGCC',
#   'RNA_2': 'AGCUGACCGAUGGGCCAAAC'},
#  'toy_circuit_combo0_535917': {'RNA_0': 'UGAACCAAGACAUACAACCU',
#   'RNA_1': 'GGCCGGGUAUGUCAUUGUUG',
#   'RNA_2': 'ACAGGCCGCAACCUACGGUA'},
#  'toy_circuit_combo0_536703': {'RNA_0': 'UAGGAGGAUUAUAGCGGUGA',
#   'RNA_1': 'CGCCAGUAAACGAAAGGUGC',
#   'RNA_2': 'AUCAUUACAUAGCUGUGGGC'},
#  'toy_circuit_combo0_537640': {'RNA_0': 'AAAUUCUAGACCAUAACACC',
#   'RNA_1': 'CCAUUUAGCCAGAGGAAGCU',
#   'RNA_2': 'UGGUGAUGACCCUGCUACGC'},
#  'toy_circuit_combo0_537852': {'RNA_0': 'UGGGAGAAGGACACGAUACU',
#   'RNA_1': 'CGCACCUCAGGUGAUAAGUG',
#   'RNA_2': 'UUUCGCCUUGGCCACAGACG'},
#  'toy_circuit_combo0_538290': {'RNA_0': 'ACACGUAGUCCUAACACCUU',
#   'RNA_1': 'UUUCGUGAAACGCUAUUUCU',
#   'RNA_2': 'UGGUGCGUGAACAUUAUGUA'},
#  'toy_circuit_combo0_538466': {'RNA_0': 'AAGCGUGGCCCCAUCCUCGU',
#   'RNA_1': 'UGUAUAACACUACCCUAAGC',
#   'RNA_2': 'UGGAUCCAGCGGAACAGGGG'},
#  'toy_circuit_combo0_539738': {'RNA_0': 'UCAACCAAGUGCUCAAGACU',
#   'RNA_1': 'CUUGACUGGCAGCUCACGAG',
#   'RNA_2': 'GAUCCAAACGAUUGCUAUGG'},
#  'toy_circuit_combo0_540039': {'RNA_0': 'UCAUUAAGAUCCGGCACACC',
#   'RNA_1': 'UUAAGGUCAAAUAUAAAUUC',
#   'RNA_2': 'CGCGCUAACGUUUGGGUUGU'},
#  'toy_circuit_combo0_540274': {'RNA_0': 'CCUCCGCGGCCCCGUCCGCC',
#   'RNA_1': 'GCAGUUCGCCGUACCACUCU',
#   'RNA_2': 'GAUCACCGAUAUAGGCGUCC'},
#  'toy_circuit_combo0_540666': {'RNA_0': 'GCCAGGGACACUGGCCCUAU',
#   'RNA_1': 'UGUAUCGAAAUCGUUUUCGA',
#   'RNA_2': 'GGAGAUCCUUGAUACUAUAG'},
#  'toy_circuit_combo0_540889': {'RNA_0': 'UCGUGUAUACUUGUAAACAC',
#   'RNA_1': 'CCCUCUGGACAUAUCCGAUU',
#   'RNA_2': 'UUGUCUGGCCACGCUGAAUC'},
#  'toy_circuit_combo0_542741': {'RNA_0': 'AUUCGCGCUUCUCUCUCCCA',
#   'RNA_1': 'CGAGUACUGCCACGUGUCCA',
#   'RNA_2': 'GACGGAGUACACUCUAUCAU'},
#  'toy_circuit_combo0_543322': {'RNA_0': 'UAGUGCUUCUCGUAAACUCU',
#   'RNA_1': 'AAUGAACUUUCCGAGGCUAU',
#   'RNA_2': 'UGAAACCUCCGGACAUCGCG'},
#  'toy_circuit_combo0_543991': {'RNA_0': 'CCGAUCUAAAUCUCGUUAUA',
#   'RNA_1': 'AUACUUUGGUGAAGGCCGAA',
#   'RNA_2': 'UGACAACUUGCGUCGAGUCC'},
#  'toy_circuit_combo0_545807': {'RNA_0': 'CAUCUACUAUAGGCAUGACG',
#   'RNA_1': 'UGGGGCGGGGGUAUGGUGCG',
#   'RNA_2': 'CAUAGAAUCUUCUACCUGCA'},
#  'toy_circuit_combo0_545835': {'RNA_0': 'CCCGUCUACCGCCUACAAAC',
#   'RNA_1': 'CCGACACGUCCGGCUCCGAC',
#   'RNA_2': 'GCGCUCAGACUAUUGUAGAU'},
#  'toy_circuit_combo0_546927': {'RNA_0': 'AGCCACUCGCGAGUAGUGCA',
#   'RNA_1': 'AAGCGCCUCAGAAAUAUAUA',
#   'RNA_2': 'GUUCACUGGUGUAUCUAGCU'},
#  'toy_circuit_combo0_547041': {'RNA_0': 'GCGGUACGGCCGGGCUUGAG',
#   'RNA_1': 'UGACAGAGGGGCUUGCGGAA',
#   'RNA_2': 'UGGUGCGUUUCGGGGAUUGA'},
#  'toy_circuit_combo0_54752': {'RNA_0': 'AACCGUGGAAAAUUGUCAGA',
#   'RNA_1': 'AUCGUAGCUACUGAGAGGUC',
#   'RNA_2': 'UGCGAUCACGGCCCAAGGAA'},
#  'toy_circuit_combo0_548300': {'RNA_0': 'CAGAUUUGGUGAAUUCGAGG',
#   'RNA_1': 'AUGCAUGUCCAAGAUCGAAC',
#   'RNA_2': 'ACAGCUAGAAUUUCAAAUCC'},
#  'toy_circuit_combo0_54847': {'RNA_0': 'UCCACUACUGGAAUGCGGAG',
#   'RNA_1': 'GACACGUCAUCCUACAAGGA',
#   'RNA_2': 'AUUGGAUGCUCGCCACCAGA'},
#  'toy_circuit_combo0_548693': {'RNA_0': 'UCAGGCCGGAUGUUACUGUU',
#   'RNA_1': 'CUAGGCACCGUGGAACGUAC',
#   'RNA_2': 'AUUCUAGUUCGUUCAGGGGU'},
#  'toy_circuit_combo0_548759': {'RNA_0': 'ACGCGUUGAGUUGAGAGGAU',
#   'RNA_1': 'AUGAGUGACGGUGCCAGAGU',
#   'RNA_2': 'UGUUGGGCCAGCUGAGAUUG'},
#  'toy_circuit_combo0_549220': {'RNA_0': 'AACUCCGUGGCGCUGCGAAG',
#   'RNA_1': 'GGGAAAGCUGCGAUAUCCAU',
#   'RNA_2': 'GAUUCUGUCGGCGAGCGGAC'},
#  'toy_circuit_combo0_549268': {'RNA_0': 'AGGACUAGCGAAAUGGUCAC',
#   'RNA_1': 'CCGUCUUAAGUCCGCUCUCA',
#   'RNA_2': 'AACUUCACAGGAACGCACUG'},
#  'toy_circuit_combo0_549987': {'RNA_0': 'UUGAAAUGGACAUGAGGUAC',
#   'RNA_1': 'UUUAGACGCUGCUCGCGAAA',
#   'RNA_2': 'AAAUUCAAAUGUCGAAAGCG'},
#  'toy_circuit_combo0_55009': {'RNA_0': 'CCGCCAUGCUAGUAUAGAGA',
#   'RNA_1': 'GCCUAUACCUCCGCAACCAU',
#   'RNA_2': 'UCCCCUACUGUACAUAGACU'},
#  'toy_circuit_combo0_550741': {'RNA_0': 'GAUUCAGGUUUGCAGAACUA',
#   'RNA_1': 'CCAUGGCAGGGCUCAAAUGU',
#   'RNA_2': 'GGGAUAACAGCUGACCCUAA'},
#  'toy_circuit_combo0_551795': {'RNA_0': 'UCAGCGGACGGCACCGCCGA',
#   'RNA_1': 'GCGGUGGAGUCGGAAACUCA',
#   'RNA_2': 'UGAAUAGGUAUCCCUCAAUA'},
#  'toy_circuit_combo0_55239': {'RNA_0': 'GAGAUUUCCUUUCCCAGACU',
#   'RNA_1': 'AGCUCCGAGCAAUGCGAUUG',
#   'RNA_2': 'AAGGUACCCAUACUGAUACC'},
#  'toy_circuit_combo0_552802': {'RNA_0': 'UACAAAACCAAAUUUUAUGA',
#   'RNA_1': 'AAUCUCGCCCGUUGGAUUCU',
#   'RNA_2': 'CUAUGACCGGGGUAUCCUGU'},
#  'toy_circuit_combo0_553256': {'RNA_0': 'UCGAUUUAGUGCUGUGGCGA',
#   'RNA_1': 'UCUUUGGCAUAAGAUGCGGU',
#   'RNA_2': 'CUACGCAAUUGCUUGCCAAU'},
#  'toy_circuit_combo0_553590': {'RNA_0': 'GUAUUGAGAGAGAAUCACGU',
#   'RNA_1': 'CCUGAAUCGUGCUGGUGUAA',
#   'RNA_2': 'GGUGAAGCGCGACUACAGCG'},
#  'toy_circuit_combo0_553739': {'RNA_0': 'UUACCAAUCGACCGGGAGUA',
#   'RNA_1': 'UCAUACCCAUUCGUUCUAAA',
#   'RNA_2': 'ACAAAUCCAGCUACCAAUAC'},
#  'toy_circuit_combo0_553819': {'RNA_0': 'UUUGUAGGAAUGUUUACCGC',
#   'RNA_1': 'UUAGUUUCAGUGGUGGCAAC',
#   'RNA_2': 'ACUGACAGGUCCGUGCGGAU'},
#  'toy_circuit_combo0_554611': {'RNA_0': 'CAGGACCGAAAAGAUGAGGA',
#   'RNA_1': 'AUGGGUUGGGAACCACGCAG',
#   'RNA_2': 'UCUCCUUACAUGCUCGAUAG'},
#  'toy_circuit_combo0_554700': {'RNA_0': 'UCUCACUGGAAAAGGCCACC',
#   'RNA_1': 'UCAGCGGCAGACUAAAGCAG',
#   'RNA_2': 'UCGUUGUUUAACUAUAGAGC'},
#  'toy_circuit_combo0_554798': {'RNA_0': 'GCGCUAUACUUCAUACUAUU',
#   'RNA_1': 'UACUCUUGGACGCGGUCACA',
#   'RNA_2': 'UGCAGUGCUCCUAUUUACCA'},
#  'toy_circuit_combo0_555095': {'RNA_0': 'ACUAUGAGCUAACUGGAGAA',
#   'RNA_1': 'AUAUACCCUAACAAAUAUAC',
#   'RNA_2': 'ACUAACCAACUUGGUAAAGG'},
#  'toy_circuit_combo0_555830': {'RNA_0': 'GUCAAGGACAUAAGUCGCCA',
#   'RNA_1': 'CGUAAGACUCCAUGUCCAUU',
#   'RNA_2': 'UUCCGCAUAGAGGUAGCAAU'},
#  'toy_circuit_combo0_556034': {'RNA_0': 'UGUGUCAGACCCAACAGAAG',
#   'RNA_1': 'CAGACAACAGAUCAUUGGAG',
#   'RNA_2': 'UGAGUCACCUACUUGAAUCC'},
#  'toy_circuit_combo0_556174': {'RNA_0': 'UGCGGCUAACAUUUGAAAUG',
#   'RNA_1': 'CGAAGGUUUGAUGCCACAAC',
#   'RNA_2': 'GGGAAAAGCGCGGAAACAAA'},
#  'toy_circuit_combo0_556613': {'RNA_0': 'GAGAUACGAUCACCUGUGUU',
#   'RNA_1': 'CUGAUUCAAGAGACAACUUG',
#   'RNA_2': 'CGCUACCGCCGCUAUUGAAG'},
#  'toy_circuit_combo0_55767': {'RNA_0': 'CAGGCAUGACAAGUGGAAUA',
#   'RNA_1': 'GCCAUUUCGCCACAACACCU',
#   'RNA_2': 'CGAUACUAUAUCCUCGGGGA'},
#  'toy_circuit_combo0_558100': {'RNA_0': 'GGGUGUGCCGCAGAUUCUGC',
#   'RNA_1': 'UUUGUAAGCCGGAGCCCUUU',
#   'RNA_2': 'UGCUAAAUUGACCCUGUUCG'},
#  'toy_circuit_combo0_558408': {'RNA_0': 'UGGCAACCUAGUGCUUACCU',
#   'RNA_1': 'GCCCAACAGUAAGUGUUCCG',
#   'RNA_2': 'AAAAGCGUACCGGGUCAGAA'},
#  'toy_circuit_combo0_55947': {'RNA_0': 'GGGCAAUUAUAACGAUGCAU',
#   'RNA_1': 'UACCGUAGACGUAGUCAAAA',
#   'RNA_2': 'GGUGUAGAUGUAGCGCAAUG'},
#  'toy_circuit_combo0_560099': {'RNA_0': 'CACCUAAAACUCCCCGGACA',
#   'RNA_1': 'GCACCAAGAGCUAAUGGAAA',
#   'RNA_2': 'ACGUAAUCCAGCCGAACUCU'},
#  'toy_circuit_combo0_561608': {'RNA_0': 'GUACAAGGAUUUGGCUUUCC',
#   'RNA_1': 'GGAGGUAGCGGCGCAAACUU',
#   'RNA_2': 'CUCAAUCAGUUUGCUGACCG'},
#  'toy_circuit_combo0_561987': {'RNA_0': 'UCAGCACCGACAACAUAAUC',
#   'RNA_1': 'UAACGAGUUACGAUCGGAAU',
#   'RNA_2': 'ACAUUGUAGUAAAAAGUAGU'},
#  'toy_circuit_combo0_562522': {'RNA_0': 'GGGACCAAUGGUCUCCUCGG',
#   'RNA_1': 'AUGAUACAACCUAGUUCCAU',
#   'RNA_2': 'CGUGGUUUUAGCCCGCUACU'},
#  'toy_circuit_combo0_562722': {'RNA_0': 'UUCUUCUGAAAAACGCCCUG',
#   'RNA_1': 'CCUGCUUCCCGUGGCCCUGA',
#   'RNA_2': 'UAGGAAACGUUGGUCUCCUC'},
#  'toy_circuit_combo0_56395': {'RNA_0': 'ACCUGGAGGUUUCGCAUGAA',
#   'RNA_1': 'CCACGCUGAAUGAAUUCCGA',
#   'RNA_2': 'AGCCCCCCCUGGACUCGAGC'},
#  'toy_circuit_combo0_563976': {'RNA_0': 'CCAUAGAGCAAAAGAAUGUA',
#   'RNA_1': 'CGGAUUGCGAGAGGUGGGCG',
#   'RNA_2': 'AUUGGAGACUGUGUGCGGGA'},
#  ...}

# %%
def reverse_mut_mapping(mut_encoding: int, sequence_type: str = 'RNA'):
    for k, v in get_mutation_type_mapping(sequence_type).items():
        if mut_encoding in list(v.values()):
            for mut, enc in v.items():
                if enc == mut_encoding:
                    return mut
    raise ValueError(
        f'Could not find mutation for mapping key {mut_encoding}.')
    
d = {v: v for v in jax.tree_util.tree_flatten(get_mutation_type_mapping('RNA'))[0]}
mutation_type_mapping_rev = jax.tree_util.tree_map(lambda x: reverse_mut_mapping(x), d)


def apply_values(sequence, indices, values):
    result = np.array(list(sequence))
    list(map(lambda idx, val: result.__setitem__(idx, val), indices, values))
    return ''.join(result)

# %% [markdown]
# Make sample sequences (mutated + normal)

# %%
data['mutation_type_explicit'] = jax.tree_util.tree_map(lambda mt: mutation_type_mapping_rev[mt], data['mutation_type'].to_list())

# %%
data['sample_seq'] = jax.tree_util.tree_map(lambda cn, sn, ms, mp, mt: fasta_d[cn][sn] if sn != ms else apply_values(fasta_d[cn][sn], mp, mt), 
                                            *[data[x].to_list() for x in ['circuit_name', 'sample_name', 'mutation_species', 'mutation_positions', 'mutation_type_explicit']])

# %%
RNA_nucs = ['A', 'C', 'G', 'U']

for l in RNA_nucs:
    data[l + '_counts'] = jax.tree_util.tree_map(lambda x: x.count(l), data['sample_seq'].to_list())

# %%
fig = plt.figure(figsize=(5 * len(RNA_nucs), 4))
fig.subplots_adjust(hspace=0.325, wspace=0.225)

for i, l in enumerate(RNA_nucs):
    ax = plt.subplot(1,len(RNA_nucs), i+1)
    sns.ecdfplot(data, x=l + '_counts', hue='mutation_num', palette='viridis_r')
    plt.title(l + ' counts')

# %% [markdown]
# Double check the energies simulated for these circuits

# %%
1201, 1231, 1233, 1234

# %%
data[data['mutation_name'] == 'RNA_0_m1-0'].index[0]
# Out:
# 3

# %%
i = 120
circuit_chosen_idx = 3*i
circuit_chosen_idx = 1085995
circuit_chosen = data.iloc[circuit_chosen_idx]
# os.listdir(os.path.join(root_dir, circuit_chosen['path_to_template_circuit'].split('circuits/')[0], 'simulated_circuits', circuit_chosen['circuit_name']))
e_dir = os.path.join(fn_random_start.split('summarise')[0], 'mutation_effect_on_interactions_signal', circuit_chosen['circuit_name'], 'mutations', circuit_chosen['mutation_name'], 'energies')
energies = pd.read_csv(os.path.join(e_dir, os.listdir(e_dir)[0]))
print(circuit_chosen[['circuit_name', 'mutation_name']])
energies
# Out:
# circuit_name     toy_circuit_combo0_999765
# mutation_name                   RNA_2_m5-8
# Name: 1085995, dtype: object
#    RNA_0  RNA_1  RNA_2_m5-8
# 0 -11.26   0.00        0.00
# 1   0.00   0.00       -6.79
# 2   0.00  -6.79        0.00

# %%
                # 'mutation_name': mutations['mutation_name'],
                # 'mutation_num': mutations['count'],
                # 'mutation_type': cast_astype(mutations['mutation_types'], int),
                # 'mutation_positions': cast_astype(mutations['positions'], int),
                # 'path_to_template_circuit': mutations['template_file']
print(e_dir)
circuit_chosen[get_true_interaction_cols(data, 'energies')]
# Out:
# ../data/ensemble_mutation_effect_analysis/2023_06_05_164913/mutation_effect_on_interactions_signal/toy_circuit_combo0_999765/mutations/RNA_2_m5-8/energies
# energies_0-0   -11.26
# energies_0-1      0.0
# energies_0-2      0.0
# energies_1-0      0.0
# energies_1-1      0.0
# energies_1-2    -6.79
# energies_2-0      0.0
# energies_2-1    -6.79
# energies_2-2      0.0
# Name: 1085995, dtype: object

# %%
from synbio_morpher.utils.data.data_format_tools.common import load_json_as_dict

# %% [markdown]
# Compare analytics

# %%
r_dir = os.path.join(fn_random_start.split('summarise')[0], 'mutation_effect_on_interactions_signal', circuit_chosen['circuit_name'], 'mutations', circuit_chosen['mutation_name'])
load_json_as_dict(os.path.join(r_dir, 'report_signal.json'))['RMSE_diff_to_base_circuit']
# Out:
# ['0.0024012683',
#  '0.0027146675',
#  '0.0027146675',
#  '0.008579154',
#  '13.268302',
#  '0.008579154',
#  '0.0007227729',
#  '13.243265',
#  '13.243265']

# %%
r_dir2 = '../data/ensemble_mutation_effect_analysis/2023_06_05_164913/mutation_effect_on_interactions_signal/toy_circuit_combo0_100192/mutations/RNA_2_m10-5'
load_json_as_dict(os.path.join(r_dir2, 'report_signal.json'))['steady_states']
# Out:
# ['0.2677884',
#  '0.032107685',
#  '0.032107685',
#  '0.0038496964',
#  '152.00607',
#  '0.0038496964',
#  '399.56625',
#  '47.90779',
#  '47.90779']

# %%
r_dir2 = '../data/ensemble_mutation_effect_analysis/2023_06_05_164913/mutation_effect_on_interactions_signal/toy_circuit_combo0_100192/mutations/RNA_0_m10-6'
load_json_as_dict(os.path.join(r_dir2, 'report_signal.json'))['steady_states']
# Out:
# ['0.26765928',
#  '0.12867911',
#  '0.12867911',
#  '0.06186341',
#  '7.699701',
#  '0.06186341',
#  '399.46994',
#  '192.04803',
#  '192.04803']

# %% [markdown]
# ## Why are the 2-3 mutations weakest, but m=5 is strong again?
#
# Look at the distribution in actual nucleotides and make sure it's the same as the initial distribution
